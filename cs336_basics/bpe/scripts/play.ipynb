# %% [markdown]
# # tokenizer

# %%
ord("a")
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
ord("😀")
# Out:
# 128512

# %%
assert ord("😀") == 128512

# %%
bytes("a", encoding = "utf-8")
# Out:
# b'a'

# %%
bytes("😀", encoding = "utf-8")
# Out:
# b'\xf0\x9f\x98\x80'

# %%
list(bytes("😀", encoding = "utf-8"))
# Out:
# [240, 159, 152, 128]

# %%
chr(0)
# Out:
# '\x00'

# %%
repr(chr(0))
# Out:
# "'\\x00'"

# %%
print(chr(0))

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %%
repr(chr(0))
len(chr(0))
len("abc" + chr(0) + "def")
# Out:
# 7

# %%
test_string ="hello! こんにちは!"
utf8_encoded = test_string.encode("utf-8")
list(utf8_encoded)
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
print(len(test_string)), print(len(utf8_encoded))
# Out:
# 13
# 23
# (None, None)

# %%
utf16_encode = test_string.encode("utf-16")
print(len(utf16_encode)), print(len(utf8_encoded))
# Out:
# 28
# 23
# (None, None)

# %%
utf16_encode
# Out:
# b'\xff\xfeh\x00e\x00l\x00l\x00o\x00!\x00 \x00S0\x930k0a0o0!\x00'

# %%
list(utf16_encode)
# Out:
# [255,
#  254,
#  104,
#  0,
#  101,
#  0,
#  108,
#  0,
#  108,
#  0,
#  111,
#  0,
#  33,
#  0,
#  32,
#  0,
#  83,
#  48,
#  147,
#  48,
#  107,
#  48,
#  97,
#  48,
#  111,
#  48,
#  33,
#  0]

# %%
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
   return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("😑".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("😑".encode("utf-8"))
#
# Cell In[32], line 2, in decode_utf8_bytes_to_str_wrong(bytestring)
#       1 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 2    return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf0 in position 0: unexpected end of data

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# 'hello'

# %% [markdown]
# this function works only for code points that are represented using a single byte, for composed code point it will not work

# %%
len("!!".encode("utf-8"))
# Out:
# 2

# %%
decode_utf8_bytes_to_str_wrong("".encode("utf-8"))
# Out:
# '. '

# %%
b1 = bin(223)
b2 = bin(223)
print(b1+b2)
# Out:
# 0b110111110b11011111

# %%
(bytes([223]) + bytes([223])).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 (bytes([223]) + bytes([223])).decode("utf-8")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xdf in position 0: invalid continuation byte

# %%
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
import regex as re
re.findall(PAT,"some text that i'll pre-tokenize")
# Out:
# ['some', ' text', ' that', ' i', "'ll", ' pre', '-', 'tokenize']

# %% [markdown]
# finditer return an iterator to avoid filling the ram, cProfile or pyspy

# %%
chunk = """u don't have to be scared of the loud dog, I'll protect you". The mole felt so safe with the little girl. She was very kind and the mole soon came to trust her. He leaned against her and she kept him safe. The mole had found his best friend.
<|endoftext|>
Once upon a time, in a warm and sunny place, there was a big pit. A little boy named Tom liked to play near the pit. One day, Tom lost his red ball. He was very sad.
Tom asked his friend, Sam, to help him search for the ball. They looked high and low, but they could not find the ball. Tom said, "I think my ball fell into the pit."
Sam and Tom went close to the pit. They were scared, but they wanted to find the red ball. They looked into the pit, but it was too dark to see. Tom said, "We must go in and search for my ball."
They went into the pit to search. It was dark and scary. They could not find the ball. They tried to get out, but the pit was too deep. Tom and Sam were stuck in the pit. They called for help, but no one could hear them. They were sad and scared, and they never got out of the pit.
<|endoftext|>


Tom and Lily were playing with their toys in the living room. They liked to build towers and bridges with their blocks and cars. Tom was very proud of his tall tower. He wanted to make it even taller, so he reached for more blocks.
"Tom, can I have some blocks too?" Lily asked. She wanted to make a bridge for her cars.
"No, these are mine. Go find your own," Tom said. He did not want to share with his sister. He pulled the blocks closer to him.
Lily felt sad and angry. She did not think Tom was being nice. She looked at his tower and had an idea. She decided to pull one of the blocks at the bottom of the tower.
Suddenly, the tower fell down with a loud crash. All the blocks and cars scattered on the floor. Tom and Lily were shocked. They felt the floor shake and heard a rumble. It was an earthquake!
"Mommy! Daddy!" they cried. They were scared and ran to their parents, who were in the kitchen.
"Are you okay, kids?" Mommy asked. She hugged them and checked if they were hurt.
"We're okay, Mommy. But our toys are broken," Lily said.
"I'm sorry, Lily. But toys are not important. You are important. We are safe and together. That's what matters," Mommy said.
Tom felt sorry for what he did. He realized he was selfish and mean to his sister. He saw how scared she was during the earthquake. He wanted to make her happy.
"Lily, I'm sorry I did not share with you. You can have all the blocks you want. I love you, sister," Tom said.
Lily smiled and hugged him. She forgave him and thanked him. She loved him too.
They went back to the living room and cleaned up their toys. They decided to build something together. They made a big house with a garden and a fence. They put their cars and dolls inside. They were happy and proud of their work.
Mommy and Daddy came to see their house. They praised them and gave them a treat. It was a lemon cake. It was sour, but they liked it. They learned that sharing is caring, and that family is sweet.
<|endoftext|>

Once upon a time there was a little girl named Lucy. She loved to go to the store to buy sweets with her mom and dad. On this special day, Lucy entered the store with her mom and dad, feeling so excited.
As they were looking around, Lucy noticed a little girl playing with a toy in the corner of the store. She gasped in excitement and ran towards her. Lucy asked if she could play too but the little girl said no. She was rather grumpy and was not in the mood to play.
Lucy's mom saw what was going on and told Lucy, "Let's try to be peaceful and kind to her. Have patience and understanding. Together, you can both be happy!"
So, Lucy smiled at the girl and said, "Can we play together?" The little girl softened and smiled back. She agreed to share the toy and even let Lucy have a turn first.
Lucy and the little girl played together happily. In the end, they both learnt an important lesson: be peaceful, kind, and understanding when faced with a conflict. And that is why Lucy and the little girl became great friends.
<|endoftext|>
One morning, a cat named Tom woke up. He felt happy because the sun was shining. Tom wanted to start his day, so he did a big stretch. He stretched his legs, his back, and his tail. It felt easy and good.
Tom went outside to play. He saw his friend, a dog named Max. Max was also stretching in the morning sun. They both felt very happy. They decided to play together and have fun all day.
At the end of the day, Tom and Max were tired. They had played all day and had lots of fun. They said goodbye to each other and went to their homes. Before going to sleep, they both did another easy stretch. Tom knew that tomorrow would be another happy morning.
<|endoftext|>


Lily and Tom were twins who liked to decorate things. They had a big box of crayons, stickers, and glitter. One day, they found a shiny copper pot in the kitchen. It was Mom's pot, but she was not home. Lily and Tom wanted to make it more pretty.
They took the pot to their room and put it on the floor. They opened their box of crayons, stickers, and glitter. They started to draw and stick and sprinkle on the pot. They made colorful shapes and patterns. They thought the pot looked very nice.
But they were clumsy. They did not see that they also made a big mess. They spilled glitter on the floor and the bed. They stuck stickers on the wall and the door. They drew crayons on the window and the dresser. They did not hear Mom come home.
Mom saw the mess in the kitchen. She saw the glitter, the stickers, and the crayons. She was angry. She followed the trail to their room. She saw the pot. She saw the floor, the bed, the wall, the door, the window, and the dresser. She was very angry.
She said, "Lily and Tom, what did you do? You ruined my pot and my room. You are very naughty. You have to clean up everything. And you have to say sorry."
Lily and Tom were scared. They did not mean to make Mom angry. They only wanted to decorate the pot. They said, "Sorry, Mom. We love you. We will clean up. Please don't be mad."
Mom sighed. She was still angry, but she also loved them. She said, "I love you too, but you have to be careful. You can't touch my things without asking. And you can't make a mess like this. You have to learn to be more tidy and respectful."
Lily and Tom nodded. They hugged Mom and said, "We will, Mom. We will." They took a broom, a dustpan, and a cloth. They started to clean up their mess. They hoped Mom would forgive them. They learned their lesson. They would not decorate Mom's pot again.
<|endoftext|>

Once upon a time, there was a king. He was a big and strong king who ruled over his kingdom. One day, he wanted to take a nice and long bath, so he filled up his big bathtub with warm water. He wanted to feel relaxed and so he soaked in the tub for a really long time.
When he had finished soaking and stepped out of the bathtub, the king noticed that the water had spilled out of the tub and all over the floor. He felt guilty that he had made such a mess, so he quickly grabbed a cloth and began to clean it up.
The king got so hot from cleaning up the mess that he decided to take another soak in the bathtub. He put a lot of bubbles in the water to make it nice and bubbly. He relaxed again and felt all the worries wash away.
The king was so happy that he had been able to clean up the mess he had made and enjoy a nice soak. He dried off and wrapped himself up in a big towel. Then, the king went back to ruling his kingdom and enjoying his lovely baths.
<|endoftext|>


Lily and Max were playing in the park with their mom. They liked to slide, swing, and run on the grass. They also liked to listen to the birds that made whistles in the trees.
"Look, mom, a red bird!" Lily said, pointing to a cardinal.
"That's a pretty bird, Lily. Do you know what it is called?" mom asked.
"A cardinal, mom. I learned it in school," Lily said proudly.
"Very good, Lily. And do you know what that yellow bird is, Max?" mom asked, pointing to a canary.
"A canary, mom. I learned it in school, too," Max said.
"Wow, you are both very smart. Do you want to learn another bird name?" mom asked.
"Yes, mom, yes!" Lily and Max said.
"OK, see that blue bird over there? That's a blue jay. It has a very loud whistle. Can you try to whistle like it?" mom asked.
Lily and Max tried to whistle, but they only made funny noises. They laughed and mom laughed, too.
"Whistling is hard, mom. How do you do it?" Lily asked.
"It takes practice, Lily. Maybe when you are older, you can whistle better. But you know what? You don't need to whistle to have fun. You can sing, or clap, or dance, or make any sound you like," mom said.
"I like to sing, mom. Can we sing a song?" Max asked.
"Sure, Max. What song do you want to sing?" mom asked.
"How about 'Twinkle, Twinkle, Little Star'?" Max suggested.
"OK, let's sing it together," mom said.
They sang the song and looked at the sky. The sun was shining and the clouds were light and fluffy.
"That was a nice song, mom. But I'm feeling sleepy now. Can we nap?" Lily asked.
"Me too, mom. Can we nap?" Max asked.
"Of course, my sweeties. Let's go to the car and nap. You had a busy day," mom said.
They walked to the car and mom buckled them in their seats. She gave them each a kiss and a hug.
"Sleep well, my loves. I'll wake you up when we get home," mom said.
Lily and Max closed their eyes and fell asleep. They dreamed of birds and stars and whistles. They were happy.
<|endoftext|>
Once upon a time, there was a big bow. The bow was very strong and reliable. It was the best bow in the town. Everyone liked the bow and wanted to use it. They knew it would help them do their work.
One day, a man wanted to test the bow. He was not a good man. He wanted to see if the bow was really strong. He pulled and pulled on the bow. He wanted to see if it would break.
The bow did not break because it was strong. But the man did not stop. He pulled harder and harder. At last, the bow broke. The man was not happy. The town was sad. They lost their best bow.
<|endoftext|>
Once upon a time, there was a little girl named Lily. She lived in a small, tidy house with her mom, dad, and her dog, Max. Lily loved to play with Max in the backyard. They would run, jump, and have lots of fun together.
One day, Lily's mom said, "Lily, I have a special treat for you and Max!" She gave Lily a big, yummy cookie and Max a tasty bone. Lily was very happy and said, "Thank you, mom!" But then, she had an idea. She wanted to save the cookie and the bone for later.
Lily put the cookie and the bone in a secret place under her bed. She forgot about them for a few days. When she remembered the treats, she found that the cookie was all broken and the bone was dirty. The treats were spoiled. Lily was sad, but she learned that it's better to enjoy treats when they are fresh and clean.
<|endoftext|>
Once upon a time, in a small house, there lived a little boy named Tim. Tim was an intelligent boy who loved to learn new things. One day, he found a big book about ghosts. He read the book and learned that ghosts could be nice or scary.
One day, Tim met a friendly ghost named Gigi. Gigi was lost and needed help. Tim wanted to show Gigi that he was a good friend. So, he picked up Gigi's favorite toy, a round ball. But, as he was playing with the ball, he accidentally let it drop. The ball broke into pieces. Tim felt sad and said sorry to Gigi.
Gigi smiled and told Tim that it was okay. She said that everyone makes mistakes. The important thing is to say sorry and learn from them. Tim learned that being a good friend means helping each other and being kind. And from that day on, Tim and Gigi became the best of friends.
<|endoftext|>
Once upon a time, in a big forest, there was a wise old owl. This owl had a long neck and knew many things. He lived in a tall tree and helped all the animals in the forest.
One day, a little bird came to the wise owl. The bird was sad because his nest was broken. The wise owl wanted to help restore the nest. They worked together to fix the nest, using sticks and leaves.
But as they were fixing the nest, a big wind came. The wind blew the nest away, and the wise owl's long neck got stuck in the tree. The little bird was sad, and the wise owl was stuck. They could not restore the nest, and the wise owl's neck hurt. The forest was not happy that day.
<|endoftext|>
Once upon a time, there was a little girl named Sue. Sue was very thoughtful. She always helped her mom and dad. One day, Sue saw her mom trying to open a door with a broken handle. Sue wanted to help her mom.
Sue asked her mom, "Can I help you?" Her mom said, "Yes, Sue. We need a new handle for the door. Can you ask dad if he has one?" Sue went to her dad and asked, "Dad, do we have a new handle for the door?" Her dad looked at Sue and said, "I am not sure, let's look together."
Sue and her dad looked for a new handle. They found one, but it was very high up. Sue's dad tried to reach it, but he couldn't. Sue had an idea. She said, "Dad, let's use a chair to stand on." Her dad refused. He said, "No, Sue. That is not safe. Let's ask mom for help." So, they asked mom for help, and she found a safe way to get the handle. They fixed the door together, and Sue felt happy that she could help her mom and dad.
<|endoftext|>"""

# %%
docs = chunk.split("<|endoftext|>")

# %%
docs
# Out:
# ['u don\'t have to be scared of the loud dog, I\'ll protect you". The mole felt so safe with the little girl. She was very kind and the mole soon came to trust her. He leaned against her and she kept him safe. The mole had found his best friend.\n',
#  '\nOnce upon a time, in a warm and sunny place, there was a big pit. A little boy named Tom liked to play near the pit. One day, Tom lost his red ball. He was very sad.\nTom asked his friend, Sam, to help him search for the ball. They looked high and low, but they could not find the ball. Tom said, "I think my ball fell into the pit."\nSam and Tom went close to the pit. They were scared, but they wanted to find the red ball. They looked into the pit, but it was too dark to see. Tom said, "We must go in and search for my ball."\nThey went into the pit to search. It was dark and scary. They could not find the ball. They tried to get out, but the pit was too deep. Tom and Sam were stuck in the pit. They called for help, but no one could hear them. They were sad and scared, and they never got out of the pit.\n',
#  '\n\n\nTom and Lily were playing with their toys in the living room. They liked to build towers and bridges with their blocks and cars. Tom was very proud of his tall tower. He wanted to make it even taller, so he reached for more blocks.\n"Tom, can I have some blocks too?" Lily asked. She wanted to make a bridge for her cars.\n"No, these are mine. Go find your own," Tom said. He did not want to share with his sister. He pulled the blocks closer to him.\nLily felt sad and angry. She did not think Tom was being nice. She looked at his tower and had an idea. She decided to pull one of the blocks at the bottom of the tower.\nSuddenly, the tower fell down with a loud crash. All the blocks and cars scattered on the floor. Tom and Lily were shocked. They felt the floor shake and heard a rumble. It was an earthquake!\n"Mommy! Daddy!" they cried. They were scared and ran to their parents, who were in the kitchen.\n"Are you okay, kids?" Mommy asked. She hugged them and checked if they were hurt.\n"We\'re okay, Mommy. But our toys are broken," Lily said.\n"I\'m sorry, Lily. But toys are not important. You are important. We are safe and together. That\'s what matters," Mommy said.\nTom felt sorry for what he did. He realized he was selfish and mean to his sister. He saw how scared she was during the earthquake. He wanted to make her happy.\n"Lily, I\'m sorry I did not share with you. You can have all the blocks you want. I love you, sister," Tom said.\nLily smiled and hugged him. She forgave him and thanked him. She loved him too.\nThey went back to the living room and cleaned up their toys. They decided to build something together. They made a big house with a garden and a fence. They put their cars and dolls inside. They were happy and proud of their work.\nMommy and Daddy came to see their house. They praised them and gave them a treat. It was a lemon cake. It was sour, but they liked it. They learned that sharing is caring, and that family is sweet.\n',
#  '\n\nOnce upon a time there was a little girl named Lucy. She loved to go to the store to buy sweets with her mom and dad. On this special day, Lucy entered the store with her mom and dad, feeling so excited.\nAs they were looking around, Lucy noticed a little girl playing with a toy in the corner of the store. She gasped in excitement and ran towards her. Lucy asked if she could play too but the little girl said no. She was rather grumpy and was not in the mood to play.\nLucy\'s mom saw what was going on and told Lucy, "Let\'s try to be peaceful and kind to her. Have patience and understanding. Together, you can both be happy!"\nSo, Lucy smiled at the girl and said, "Can we play together?" The little girl softened and smiled back. She agreed to share the toy and even let Lucy have a turn first.\nLucy and the little girl played together happily. In the end, they both learnt an important lesson: be peaceful, kind, and understanding when faced with a conflict. And that is why Lucy and the little girl became great friends.\n',
#  '\nOne morning, a cat named Tom woke up. He felt happy because the sun was shining. Tom wanted to start his day, so he did a big stretch. He stretched his legs, his back, and his tail. It felt easy and good.\nTom went outside to play. He saw his friend, a dog named Max. Max was also stretching in the morning sun. They both felt very happy. They decided to play together and have fun all day.\nAt the end of the day, Tom and Max were tired. They had played all day and had lots of fun. They said goodbye to each other and went to their homes. Before going to sleep, they both did another easy stretch. Tom knew that tomorrow would be another happy morning.\n',
#  '\n\n\nLily and Tom were twins who liked to decorate things. They had a big box of crayons, stickers, and glitter. One day, they found a shiny copper pot in the kitchen. It was Mom\'s pot, but she was not home. Lily and Tom wanted to make it more pretty.\nThey took the pot to their room and put it on the floor. They opened their box of crayons, stickers, and glitter. They started to draw and stick and sprinkle on the pot. They made colorful shapes and patterns. They thought the pot looked very nice.\nBut they were clumsy. They did not see that they also made a big mess. They spilled glitter on the floor and the bed. They stuck stickers on the wall and the door. They drew crayons on the window and the dresser. They did not hear Mom come home.\nMom saw the mess in the kitchen. She saw the glitter, the stickers, and the crayons. She was angry. She followed the trail to their room. She saw the pot. She saw the floor, the bed, the wall, the door, the window, and the dresser. She was very angry.\nShe said, "Lily and Tom, what did you do? You ruined my pot and my room. You are very naughty. You have to clean up everything. And you have to say sorry."\nLily and Tom were scared. They did not mean to make Mom angry. They only wanted to decorate the pot. They said, "Sorry, Mom. We love you. We will clean up. Please don\'t be mad."\nMom sighed. She was still angry, but she also loved them. She said, "I love you too, but you have to be careful. You can\'t touch my things without asking. And you can\'t make a mess like this. You have to learn to be more tidy and respectful."\nLily and Tom nodded. They hugged Mom and said, "We will, Mom. We will." They took a broom, a dustpan, and a cloth. They started to clean up their mess. They hoped Mom would forgive them. They learned their lesson. They would not decorate Mom\'s pot again.\n',
#  '\n\nOnce upon a time, there was a king. He was a big and strong king who ruled over his kingdom. One day, he wanted to take a nice and long bath, so he filled up his big bathtub with warm water. He wanted to feel relaxed and so he soaked in the tub for a really long time.\nWhen he had finished soaking and stepped out of the bathtub, the king noticed that the water had spilled out of the tub and all over the floor. He felt guilty that he had made such a mess, so he quickly grabbed a cloth and began to clean it up.\nThe king got so hot from cleaning up the mess that he decided to take another soak in the bathtub. He put a lot of bubbles in the water to make it nice and bubbly. He relaxed again and felt all the worries wash away.\nThe king was so happy that he had been able to clean up the mess he had made and enjoy a nice soak. He dried off and wrapped himself up in a big towel. Then, the king went back to ruling his kingdom and enjoying his lovely baths.\n',
#  '\n\n\nLily and Max were playing in the park with their mom. They liked to slide, swing, and run on the grass. They also liked to listen to the birds that made whistles in the trees.\n"Look, mom, a red bird!" Lily said, pointing to a cardinal.\n"That\'s a pretty bird, Lily. Do you know what it is called?" mom asked.\n"A cardinal, mom. I learned it in school," Lily said proudly.\n"Very good, Lily. And do you know what that yellow bird is, Max?" mom asked, pointing to a canary.\n"A canary, mom. I learned it in school, too," Max said.\n"Wow, you are both very smart. Do you want to learn another bird name?" mom asked.\n"Yes, mom, yes!" Lily and Max said.\n"OK, see that blue bird over there? That\'s a blue jay. It has a very loud whistle. Can you try to whistle like it?" mom asked.\nLily and Max tried to whistle, but they only made funny noises. They laughed and mom laughed, too.\n"Whistling is hard, mom. How do you do it?" Lily asked.\n"It takes practice, Lily. Maybe when you are older, you can whistle better. But you know what? You don\'t need to whistle to have fun. You can sing, or clap, or dance, or make any sound you like," mom said.\n"I like to sing, mom. Can we sing a song?" Max asked.\n"Sure, Max. What song do you want to sing?" mom asked.\n"How about \'Twinkle, Twinkle, Little Star\'?" Max suggested.\n"OK, let\'s sing it together," mom said.\nThey sang the song and looked at the sky. The sun was shining and the clouds were light and fluffy.\n"That was a nice song, mom. But I\'m feeling sleepy now. Can we nap?" Lily asked.\n"Me too, mom. Can we nap?" Max asked.\n"Of course, my sweeties. Let\'s go to the car and nap. You had a busy day," mom said.\nThey walked to the car and mom buckled them in their seats. She gave them each a kiss and a hug.\n"Sleep well, my loves. I\'ll wake you up when we get home," mom said.\nLily and Max closed their eyes and fell asleep. They dreamed of birds and stars and whistles. They were happy.\n',
#  '\nOnce upon a time, there was a big bow. The bow was very strong and reliable. It was the best bow in the town. Everyone liked the bow and wanted to use it. They knew it would help them do their work.\nOne day, a man wanted to test the bow. He was not a good man. He wanted to see if the bow was really strong. He pulled and pulled on the bow. He wanted to see if it would break.\nThe bow did not break because it was strong. But the man did not stop. He pulled harder and harder. At last, the bow broke. The man was not happy. The town was sad. They lost their best bow.\n',
#  '\nOnce upon a time, there was a little girl named Lily. She lived in a small, tidy house with her mom, dad, and her dog, Max. Lily loved to play with Max in the backyard. They would run, jump, and have lots of fun together.\nOne day, Lily\'s mom said, "Lily, I have a special treat for you and Max!" She gave Lily a big, yummy cookie and Max a tasty bone. Lily was very happy and said, "Thank you, mom!" But then, she had an idea. She wanted to save the cookie and the bone for later.\nLily put the cookie and the bone in a secret place under her bed. She forgot about them for a few days. When she remembered the treats, she found that the cookie was all broken and the bone was dirty. The treats were spoiled. Lily was sad, but she learned that it\'s better to enjoy treats when they are fresh and clean.\n',
#  "\nOnce upon a time, in a small house, there lived a little boy named Tim. Tim was an intelligent boy who loved to learn new things. One day, he found a big book about ghosts. He read the book and learned that ghosts could be nice or scary.\nOne day, Tim met a friendly ghost named Gigi. Gigi was lost and needed help. Tim wanted to show Gigi that he was a good friend. So, he picked up Gigi's favorite toy, a round ball. But, as he was playing with the ball, he accidentally let it drop. The ball broke into pieces. Tim felt sad and said sorry to Gigi.\nGigi smiled and told Tim that it was okay. She said that everyone makes mistakes. The important thing is to say sorry and learn from them. Tim learned that being a good friend means helping each other and being kind. And from that day on, Tim and Gigi became the best of friends.\n",
#  "\nOnce upon a time, in a big forest, there was a wise old owl. This owl had a long neck and knew many things. He lived in a tall tree and helped all the animals in the forest.\nOne day, a little bird came to the wise owl. The bird was sad because his nest was broken. The wise owl wanted to help restore the nest. They worked together to fix the nest, using sticks and leaves.\nBut as they were fixing the nest, a big wind came. The wind blew the nest away, and the wise owl's long neck got stuck in the tree. The little bird was sad, and the wise owl was stuck. They could not restore the nest, and the wise owl's neck hurt. The forest was not happy that day.\n",
#  '\nOnce upon a time, there was a little girl named Sue. Sue was very thoughtful. She always helped her mom and dad. One day, Sue saw her mom trying to open a door with a broken handle. Sue wanted to help her mom.\nSue asked her mom, "Can I help you?" Her mom said, "Yes, Sue. We need a new handle for the door. Can you ask dad if he has one?" Sue went to her dad and asked, "Dad, do we have a new handle for the door?" Her dad looked at Sue and said, "I am not sure, let\'s look together."\nSue and her dad looked for a new handle. They found one, but it was very high up. Sue\'s dad tried to reach it, but he couldn\'t. Sue had an idea. She said, "Dad, let\'s use a chair to stand on." Her dad refused. He said, "No, Sue. That is not safe. Let\'s ask mom for help." So, they asked mom for help, and she found a safe way to get the handle. They fixed the door together, and Sue felt happy that she could help her mom and dad.\n',
#  '']

# %%
size(docs)
# Out:
# 14

# %%
for doc in docs:
   for match in re.finditer(PAT, doc):
      print(type(match.group(0)))
      break
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
iterator

# %%
special_tokens = ["<|endoftext|>"]

segment_delimiter = "|".join(special_tokens)

docs = chunk.split(segment_delimiter)

# %%
size(docs)
# Out:
# 14

# %%
match.group(0)
# Out:
# '\n'

# %%
st = "hello"
len(st)
# Out:
# 5

# %%
for i in range(len(st)-1):
   print(st[i])
# Out:
# h
# e
# l
# l

# %%
dict = { i : chr(i) for i in range(255)}

# %%
ord(dict[0])
# Out:
# 0

# %%
type(ord(chr(0)))
# Out:
# int

# %%
dict[0]
# Out:
# '\x00'

# %%
type(ord(dict[0]))
# Out:
# int

# %%
# I need to build the vocab, mapping each Id that is an int to a sequence of byte, each character has a unique uncideo code point that is made of bytes.
# How can I obtain the bytes? I need to convert the charcater in utf-8
"".encode("utf-8")[0]
# Out:
# 98

# %%
for i in range(256):
   print(i,bytes([i]),bytes([i]).decode("utf-8"))
# Out:
# 0 b'\x00'
# 1 b'\x01'
# 2 b'\x02'
# 3 b'\x03'
# 4 b'\x04'
# 5 b'\x05'
# 6 b'\x06'
# 7 b'\x07'
# 8 b'\x08'
# 9 b'\t'
# 10 b'\n'
#
# 11 b'\x0b'
# 12 b'\x0c'
# 13 b'\r'
# 14 b'\x0e'
# 15 b'\x0f'
# 16 b'\x10'
# 17 b'\x11'
# 18 b'\x12'
# 19 b'\x13'
# 20 b'\x14'
# 21 b'\x15'
# 22 b'\x16'
# 23 b'\x17'
# 24 b'\x18'
# 25 b'\x19'
# 26 b'\x1a'
# 27 b'\x1b'
# 28 b'\x1c'
# 29 b'\x1d'
# 30 b'\x1e'
# 31 b'\x1f'
# 32 b' '
# 33 b'!' !
# 34 b'"' "
# 35 b'#' #
# 36 b'$' $
# 37 b'%' %
# 38 b'&' &
# 39 b"'" '
# 40 b'(' (
# 41 b')' )
# 42 b'*' *
# 43 b'+' +
# 44 b',' ,
# 45 b'-' -
# 46 b'.' .
# 47 b'/' /
# 48 b'0' 0
# 49 b'1' 1
# 50 b'2' 2
# 51 b'3' 3
# 52 b'4' 4
# 53 b'5' 5
# 54 b'6' 6
# 55 b'7' 7
# 56 b'8' 8
# 57 b'9' 9
# 58 b':' :
# 59 b';' ;
# 60 b'<' <
# 61 b'=' =
# 62 b'>' >
# 63 b'?' ?
# 64 b'@' @
# 65 b'A' A
# 66 b'B' B
# 67 b'C' C
# 68 b'D' D
# 69 b'E' E
# 70 b'F' F
# 71 b'G' G
# 72 b'H' H
# 73 b'I' I
# 74 b'J' J
# 75 b'K' K
# 76 b'L' L
# 77 b'M' M
# 78 b'N' N
# 79 b'O' O
# 80 b'P' P
# 81 b'Q' Q
# 82 b'R' R
# 83 b'S' S
# 84 b'T' T
# 85 b'U' U
# 86 b'V' V
# 87 b'W' W
# 88 b'X' X
# 89 b'Y' Y
# 90 b'Z' Z
# 91 b'[' [
# 92 b'\\' \
# 93 b']' ]
# 94 b'^' ^
# 95 b'_' _
# 96 b'`' `
# 97 b'a' a
# 98 b'b' b
# 99 b'c' c
# 100 b'd' d
# 101 b'e' e
# 102 b'f' f
# 103 b'g' g
# 104 b'h' h
# 105 b'i' i
# 106 b'j' j
# 107 b'k' k
# 108 b'l' l
# 109 b'm' m
# 110 b'n' n
# 111 b'o' o
# 112 b'p' p
# 113 b'q' q
# 114 b'r' r
# 115 b's' s
# 116 b't' t
# 117 b'u' u
# 118 b'v' v
# 119 b'w' w
# 120 b'x' x
# 121 b'y' y
# 122 b'z' z
# 123 b'{' {
# 124 b'|' |
# 125 b'}' }
# 126 b'~' ~
# 127 b'\x7f'
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in range(256):
# ----> 2    print(i,bytes([i]),bytes([i]).decode("utf-8"))
#       3
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
sp = "<|endoftext|>"
# I need to add it in the vocab as b
type(sp.encode("utf-8"))
# Out:
# bytes

# %%
import pickle

with open("scripts/tinystories_bpe.pkl", "rb") as f:
    data = pickle.load(f)

print(type(data))
print(data.keys())

vocab = data["vocab"]
merges = data["merges"]

print(type(vocab), len(vocab))
print(type(merges), len(merges))

print(list(vocab.items())[:20])
print(merges[:20])
# Out:
# <class 'dict'>
# dict_keys(['vocab', 'merges'])
# <class 'dict'> 10000
# <class 'list'> 9743
# [(0, b'\x00'), (1, b'\x01'), (2, b'\x02'), (3, b'\x03'), (4, b'\x04'), (5, b'\x05'), (6, b'\x06'), (7, b'\x07'), (8, b'\x08'), (9, b'\t'), (10, b'\n'), (11, b'\x0b'), (12, b'\x0c'), (13, b'\r'), (14, b'\x0e'), (15, b'\x0f'), (16, b'\x10'), (17, b'\x11'), (18, b'\x12'), (19, b'\x13')]
# [(b' ', b't'), (b'h', b'e'), (b' ', b'a'), (b' ', b's'), (b' ', b'w'), (b'n', b'd'), (b' t', b'he'), (b'e', b'd'), (b' ', b'b'), (b' t', b'o'), (b' a', b'nd'), (b' ', b'h'), (b' ', b'f'), (b'i', b'n'), (b' ', b'T'), (b' w', b'a'), (b'r', b'e'), (b'i', b't'), (b'o', b'u'), (b' ', b'l')]

# %%
import pickle

PICKLE_PATH = "scripts/tinystories_bpe.pkl"  

with open(PICKLE_PATH, "rb") as f:
    data = pickle.load(f)

vocab = data["vocab"]
merges = data["merges"]

print(f"Vocabulary size: {len(vocab)}")
print(f"Number of merges: {len(merges)}")

longest_id, longest_token = max(
    vocab.items(),
    key=lambda item: len(item[1]),
)

print("Longest token:")
print("id:", longest_id)
print("bytes:", repr(longest_token))
print("length:", len(longest_token), "bytes")
print("decoded:", repr(longest_token.decode("utf-8", errors="replace")))
# Out:
# Vocabulary size: 10000
# Number of merges: 9743
# Longest token:
# id: 7159
# bytes: b' accomplishment'
# length: 15 bytes
# decoded: ' accomplishment'

# %%
longest_tokens = sorted(
    vocab.items(),
    key=lambda item: len(item[1]),
    reverse=True,
)

for token_id, token in longest_tokens[:20]:
    print(
        token_id,
        len(token),
        repr(token.decode("utf-8", errors="replace"))
    )
# Out:
# 7159 15 ' accomplishment'
# 9142 15 ' disappointment'
# 9378 15 ' responsibility'
# 3227 14 ' uncomfortable'
# 3514 14 ' compassionate'
# 5318 14 ' understanding'
# 6385 14 ' neighbourhood'
# 6496 14 ' Unfortunately'
# 6873 14 ' determination'
# 7755 14 ' encouragement'
# 8625 14 ' unfortunately'
# 8698 14 ' congratulated'
# 8867 14 ' extraordinary'
# 9094 14 ' granddaughter'
# 3337 13 ' disappointed'
# 3768 13 ' enthusiastic'
# 4359 13 ' accidentally'
# 4375 13 ' refrigerator'
# 4471 13 ' veterinarian'
# 4800 13 ' strawberries'

# %%
import pickle

with open("/home/tom/machine-learning/assignment1-basics/data/tinystories_bpe.pkl", "rb") as f:
    data = pickle.load(f)

vocab = data["vocab"]
merges = data["merges"]

# %%
import pickle

DATA_DIR = "/home/tom/machine-learning/assignment1-basics/data"

with open(f"{DATA_DIR}/tinystories_vocab.pkl", "wb") as f:
    pickle.dump(vocab, f)

with open(f"{DATA_DIR}/tinystories_merges.pkl", "wb") as f:
    pickle.dump(merges, f)

# %%
merges
# Out:
# [(b' ', b't'),
#  (b'h', b'e'),
#  (b' ', b'a'),
#  (b' ', b's'),
#  (b' ', b'w'),
#  (b'n', b'd'),
#  (b' t', b'he'),
#  (b'e', b'd'),
#  (b' ', b'b'),
#  (b' t', b'o'),
#  (b' a', b'nd'),
#  (b' ', b'h'),
#  (b' ', b'f'),
#  (b'i', b'n'),
#  (b' ', b'T'),
#  (b' w', b'a'),
#  (b'r', b'e'),
#  (b'i', b't'),
#  (b'o', b'u'),
#  (b' ', b'l'),
#  (b' ', b'd'),
#  (b' ', b'c'),
#  (b' ', b'p'),
#  (b'a', b'y'),
#  (b' ', b'm'),
#  (b'e', b'r'),
#  (b' wa', b's'),
#  (b'o', b'm'),
#  (b' T', b'he'),
#  (b' ', b'he'),
#  (b'i', b's'),
#  (b'a', b'r'),
#  (b' ', b'n'),
#  (b'i', b'm'),
#  (b'o', b'n'),
#  (b' s', b'a'),
#  (b'i', b'd'),
#  (b'l', b'l'),
#  (b' h', b'a'),
#  (b' ', b'g'),
#  (b'a', b't'),
#  (b' ', b'S'),
#  (b'in', b'g'),
#  (b'o', b't'),
#  (b'e', b'n'),
#  (b'a', b'n'),
#  (b'l', b'e'),
#  (b'o', b'r'),
#  (b'i', b'r'),
#  (b'a', b'm'),
#  (b'e', b't'),
#  (b' ', b'H'),
#  (b' ', b'it'),
#  (b' t', b'h'),
#  (b'i', b'g'),
#  (b' The', b'y'),
#  (b' ', b'in'),
#  (b'i', b'l'),
#  (b' p', b'l'),
#  (b' H', b'e'),
#  (b' ', b'"'),
#  (b'o', b'w'),
#  (b'v', b'er'),
#  (b'r', b'i'),
#  (b'u', b't'),
#  (b' b', b'e'),
#  (b' ', b'u'),
#  (b' sa', b'id'),
#  (b' pl', b'ay'),
#  (b'it', b'h'),
#  (b' d', b'ay'),
#  (b' w', b'ith'),
#  (b'p', b'p'),
#  (b'O', b'n'),
#  (b' ', b'o'),
#  (b' ', b'y'),
#  (b'o', b'o'),
#  (b'k', b'ed'),
#  (b' ', b'r'),
#  (b' he', b'r'),
#  (b'c', b'e'),
#  (b' ', b'I'),
#  (b' S', b'he'),
#  (b'l', b'd'),
#  (b' T', b'im'),
#  (b' h', b'is'),
#  (b' s', b't'),
#  (b'k', b'e'),
#  (b' ', b'e'),
#  (b' b', b'ig'),
#  (b'n', b't'),
#  (b'c', b'k'),
#  (b' y', b'ou'),
#  (b'ver', b'y'),
#  (b's', b't'),
#  (b'v', b'e'),
#  (b'e', b'nd'),
#  (b' ', b'on'),
#  (b'u', b'n'),
#  (b' ha', b'pp'),
#  (b'ri', b'end'),
#  (b' f', b'riend'),
#  (b'a', b'll'),
#  (b'il', b'y'),
#  (b' ', b'L'),
#  (b' the', b'y'),
#  (b' w', b'e'),
#  (b' ha', b'd'),
#  (b' n', b'ot'),
#  (b' l', b'i'),
#  (b' u', b'p'),
#  (b'he', b'r'),
#  (b' wa', b'nt'),
#  (b' o', b'f'),
#  (b'a', b'd'),
#  (b'it', b't'),
#  (b's', b'e'),
#  (b' ', b'B'),
#  (b' d', b'o'),
#  (b' happ', b'y'),
#  (b'en', b't'),
#  (b' ', b'very'),
#  (b' ', b'M'),
#  (b'e', b's'),
#  (b' th', b'at'),
#  (b' sa', b'w'),
#  (b'On', b'e'),
#  (b"'", b's'),
#  (b'ou', b'ld'),
#  (b' m', b'om'),
#  (b' f', b'or'),
#  (b' s', b'h'),
#  (b'itt', b'le'),
#  (b' l', b'ittle'),
#  (b' s', b'o'),
#  (b' s', b'he'),
#  (b'c', b'h'),
#  (b'im', b'e'),
#  (b' n', b'e'),
#  (b' n', b'am'),
#  (b'.', b'"'),
#  (b' t', b'ime'),
#  (b' ', b'k'),
#  (b'ou', b'nd'),
#  (b' the', b're'),
#  (b' nam', b'ed'),
#  (b' s', b'm'),
#  (b' b', b'o'),
#  (b' we', b're'),
#  (b' L', b'ily'),
#  (b' want', b'ed'),
#  (b' b', b'ut'),
#  (b'ou', b't'),
#  (b'T', b'he'),
#  (b' friend', b's'),
#  (b'v', b'ed'),
#  (b'!', b'"'),
#  (b'h', b't'),
#  (b' T', b'om'),
#  (b'ir', b'd'),
#  (b'e', b'l'),
#  (b' b', b'ird'),
#  (b'a', b'l'),
#  (b' a', b'n'),
#  (b'a', b'ke'),
#  (b' to', b'o'),
#  (b'om', b'e'),
#  (b' I', b't'),
#  (b'u', b'g'),
#  (b'id', b'e'),
#  (b' w', b'ent'),
#  (b' w', b'h'),
#  (b' he', b'l'),
#  (b'On', b'ce'),
#  (b' ', b'is'),
#  (b' a', b'll'),
#  (b' hel', b'p'),
#  (b'u', b'e'),
#  (b' l', b'oo'),
#  (b' l', b'o'),
#  (b't', b'er'),
#  (b' ', b'A'),
#  (b' up', b'on'),
#  (b'r', b'y'),
#  (b'o', b're'),
#  (b'i', b'nd'),
#  (b' f', b'un'),
#  (b'g', b'et'),
#  (b' to', b'y'),
#  (b'i', b'll'),
#  (b'am', b'e'),
#  (b' a', b's'),
#  (b' a', b't'),
#  (b'r', b'a'),
#  (b' ', b'j'),
#  (b' d', b'id'),
#  (b'get', b'her'),
#  (b' ', b're'),
#  (b'u', b'r'),
#  (b' s', b'e'),
#  (b' to', b'gether'),
#  (b'a', b'ck'),
#  (b' c', b'at'),
#  (b'l', b'y'),
#  (b' t', b're'),
#  (b'oo', b'd'),
#  (b'i', b'c'),
#  (b't', b'ed'),
#  (b' do', b'g'),
#  (b' c', b'ould'),
#  (b' c', b'an'),
#  (b' the', b'ir'),
#  (b'ar', b'd'),
#  (b'e', b'c'),
#  (b'ar', b'k'),
#  (b' g', b'ir'),
#  (b' play', b'ed'),
#  (b' h', b'im'),
#  (b' b', b'all'),
#  (b'?', b'"'),
#  (b' gir', b'l'),
#  (b'w', b'ay'),
#  (b' r', b'o'),
#  (b' g', b'o'),
#  (b'he', b'd'),
#  (b'm', b'y'),
#  (b' a', b're'),
#  (b' ', b'out'),
#  (b' l', b'e'),
#  (b' f', b'r'),
#  (b'a', b'in'),
#  (b' k', b'n'),
#  (b'he', b'n'),
#  (b' the', b'm'),
#  (b'u', b'm'),
#  (b"'", b't'),
#  (b'a', b'x'),
#  (b' sa', b'd'),
#  (b'u', b'l'),
#  (b' bo', b'y'),
#  (b' tre', b'e'),
#  (b'ot', b'her'),
#  (b' ha', b've'),
#  (b' m', b'an'),
#  (b' c', b'l'),
#  (b' lo', b'ved'),
#  (b' loo', b'ked'),
#  (b'ou', b'g'),
#  (b' f', b'ound'),
#  (b' s', b'p'),
#  (b' st', b'ar'),
#  (b' S', b'ue'),
#  (b'on', b'e'),
#  (b'h', b'ing'),
#  (b' s', b'c'),
#  (b' b', b'ack'),
#  (b'ow', b'n'),
#  (b' M', b'ax'),
#  (b'a', b're'),
#  (b' li', b'ke'),
#  (b'f', b'ul'),
#  (b's', b'ide'),
#  (b' m', b'e'),
#  (b' be', b'c'),
#  (b' p', b'ark'),
#  (b'ig', b'ht'),
#  (b'on', b'g'),
#  (b' c', b'ar'),
#  (b'o', b'p'),
#  (b'el', b't'),
#  (b' ', b'One'),
#  (b' li', b'ked'),
#  (b' w', b'ould'),
#  (b' m', b'ake'),
#  (b'r', b'ound'),
#  (b' l', b'a'),
#  (b' f', b'a'),
#  (b' f', b'elt'),
#  (b'Y', b'ou'),
#  (b' ', b'W'),
#  (b'e', b'll'),
#  (b' se', b'e'),
#  (b' B', b'ut'),
#  (b'om', b'et'),
#  (b' as', b'ked'),
#  (b'a', b'g'),
#  (b' ne', b'w'),
#  (b' n', b'o'),
#  (b'i', b'ce'),
#  (b' S', b'am'),
#  (b'ou', b'se'),
#  (b' star', b'ted'),
#  (b'ar', b'ed'),
#  (b' c', b'ame'),
#  (b' B', b'en'),
#  (b' a', b'l'),
#  (b' ', b'other'),
#  (b'oug', b'ht'),
#  (b'il', b'ed'),
#  (b' s', b'omet'),
#  (b' a', b'g'),
#  (b' g', b'ood'),
#  (b' sm', b'all'),
#  (b's', b's'),
#  (b' b', b'r'),
#  (b' sm', b'iled'),
#  (b' s', b'ay'),
#  (b'ri', b'ed'),
#  (b'ad', b'e'),
#  (b'ing', b's'),
#  (b'o', b'b'),
#  (b'p', b'ot'),
#  (b' w', b'or'),
#  (b' f', b'ind'),
#  (b' e', b'x'),
#  (b'i', b'a'),
#  (b' a', b'way'),
#  (b't', b'y'),
#  (b' p', b'ut'),
#  (b' wh', b'at'),
#  (b' somet', b'hing'),
#  (b' c', b'o'),
#  (b' fr', b'om'),
#  (b' m', b'ade'),
#  (b' th', b'ought'),
#  (b'en', b'ed'),
#  (b' h', b'ome'),
#  (b' play', b'ing'),
#  (b'oo', b'k'),
#  (b' e', b'very'),
#  (b' wa', b'l'),
#  (b' m', b'u'),
#  (b'u', b'c'),
#  (b'a', b'ch'),
#  (b'ar', b'n'),
#  (b' S', b'pot'),
#  (b' r', b'an'),
#  (b'i', b'le'),
#  (b' ', b'F'),
#  (b'i', b'e'),
#  (b' ', b'J'),
#  (b'a', b've'),
#  (b' ag', b'ain'),
#  (b' s', b'ome'),
#  (b' la', b'ug'),
#  (b'd', b'd'),
#  (b' h', b'ouse'),
#  (b' d', b'own'),
#  (b' f', b'l'),
#  (b'k', b'ing'),
#  (b' too', b'k'),
#  (b' sc', b'ared'),
#  (b' p', b'r'),
#  (b'n', b'y'),
#  (b'u', b're'),
#  (b' toy', b's'),
#  (b' le', b'arn'),
#  (b' ', b'You'),
#  (b'i', b'f'),
#  (b' w', b'ill'),
#  (b' bo', b'x'),
#  (b'i', b'ck'),
#  (b're', b't'),
#  (b'a', b'b'),
#  (b'e', b'p'),
#  (b' m', b'y'),
#  (b' a', b'round'),
#  (b' th', b'ings'),
#  (b' you', b'r'),
#  (b'ou', b'd'),
#  (b' b', b'l'),
#  (b'u', b'ck'),
#  (b' w', b'hen'),
#  (b'is', b'h'),
#  (b' li', b'ved'),
#  (b' f', b'e'),
#  (b' the', b'n'),
#  (b' s', b'un'),
#  (b'a', b's'),
#  (b' s', b'w'),
#  (b',', b'"'),
#  (b' c', b'h'),
#  (b'u', b's'),
#  (b'pp', b'ed'),
#  (b' a', b'b'),
#  (b' M', b'ia'),
#  (b'an', b'k'),
#  (b' g', b'et'),
#  (b'uc', b'y'),
#  (b'T', b'im'),
#  (b'um', b'p'),
#  (b'T', b'h'),
#  (b' l', b'ot'),
#  (b'is', b't'),
#  (b'ot', b'h'),
#  (b' t', b'ried'),
#  (b'a', b'p'),
#  (b' kn', b'ow'),
#  (b' say', b's'),
#  (b' g', b'ot'),
#  (b'it', b'ed'),
#  (b' wh', b'o'),
#  (b' kn', b'e'),
#  (b'u', b'st'),
#  (b' man', b'y'),
#  (b'nd', b'er'),
#  (b' in', b't'),
#  (b' ab', b'out'),
#  (b'L', b'ily'),
#  (b' p', b'ret'),
#  (b' d', b'ec'),
#  (b' an', b'y'),
#  (b' r', b'ed'),
#  (b' ', b'D'),
#  (b'i', b've'),
#  (b' kne', b'w'),
#  (b'a', b'ce'),
#  (b'ou', b's'),
#  (b' m', b'ore'),
#  (b'is', b'e'),
#  (b' c', b'are'),
#  (b'all', b'y'),
#  (b' p', b'ic'),
#  (b'a', b'u'),
#  (b'q', b'u'),
#  (b' h', b'ug'),
#  (b' L', b'ucy'),
#  (b' learn', b'ed'),
#  (b' p', b'o'),
#  (b' wa', b'ter'),
#  (b'f', b'ter'),
#  (b' ', b'v'),
#  (b' bec', b'ame'),
#  (b' be', b'st'),
#  (b'au', b'se'),
#  (b' o', b'p'),
#  (b' g', b're'),
#  (b' ex', b'c'),
#  (b'ur', b'p'),
#  (b'way', b's'),
#  (b'\xe2', b'\x80'),
#  (b' out', b'side'),
#  (b' laug', b'hed'),
#  (b' loo', b'k'),
#  (b' al', b'ways'),
#  (b' dec', b'id'),
#  (b' sh', b'ow'),
#  (b' u', b'n'),
#  (b'an', b't'),
#  (b' B', b'ob'),
#  (b' ro', b'om'),
#  (b'f', b'e'),
#  (b' decid', b'ed'),
#  (b' h', b'o'),
#  (b' bec', b'ause'),
#  (b' S', b'o'),
#  (b' int', b'o'),
#  (b' e', b'at'),
#  (b'it', b'e'),
#  (b' j', b'ump'),
#  (b' A', b'nd'),
#  (b' p', b'e'),
#  (b' b', b'oth'),
#  (b'er', b's'),
#  (b' M', b'om'),
#  (b' d', b'ad'),
#  (b'The', b'y'),
#  (b'u', b'dd'),
#  (b' ', b'ke'),
#  (b' on', b'e'),
#  (b'n', b'n'),
#  (b' th', b'is'),
#  (b' exc', b'ited'),
#  (b' fa', b'st'),
#  (b' n', b'ice'),
#  (b' ', b'E'),
#  (b' fe', b'el'),
#  (b'T', b'om'),
#  (b'Y', b'es'),
#  (b' r', b'un'),
#  (b' l', b'ong'),
#  (b' to', b'ld'),
#  (b' s', b'k'),
#  (b' a', b'm'),
#  (b'urp', b'r'),
#  (b'ou', b'r'),
#  (b' in', b'side'),
#  (b'u', b'll'),
#  (b' t', b'r'),
#  (b' s', b'urpr'),
#  (b' m', b'o'),
#  (b'in', b'k'),
#  (b' pret', b'ty'),
#  (b'in', b'y'),
#  (b' s', b'or'),
#  (b'W', b'h'),
#  (b' t', b'ake'),
#  (b'o', b'g'),
#  (b' s', b'l'),
#  (b' e', b'ach'),
#  (b' g', b'ave'),
#  (b' mu', b'ch'),
#  (b' g', b'ra'),
#  (b'le', b'w'),
#  (b'nn', b'a'),
#  (b' ro', b'ck'),
#  (b' h', b'ow'),
#  (b' st', b'r'),
#  (b'ar', b'a'),
#  (b'im', b'al'),
#  (b' an', b'imal'),
#  (b'g', b'ed'),
#  (b' ne', b'ed'),
#  (b' th', b'an'),
#  (b'B', b'ut'),
#  (b'v', b'en'),
#  (b'et', b'ter'),
#  (b' to', b'w'),
#  (b' ', b'or'),
#  (b' ', b'C'),
#  (b' u', b'nder'),
#  (b'es', b's'),
#  (b' o', b'ld'),
#  (b' sor', b'ry'),
#  (b'g', b'e'),
#  (b'is', b'ed'),
#  (b'r', b'o'),
#  (b'ur', b't'),
#  (b' c', b'le'),
#  (b' f', b'ish'),
#  (b' wal', b'ked'),
#  (b' cl', b'o'),
#  (b'a', b'nd'),
#  (b' be', b'ar'),
#  (b'f', b't'),
#  (b'a', b'se'),
#  (b'a', b'st'),
#  (b' ha', b'nd'),
#  (b'ur', b'n'),
#  (b' W', b'e'),
#  (b' k', b'ind'),
#  (b' H', b'is'),
#  (b' t', b'e'),
#  (b'he', b're'),
#  (b' happ', b'ened'),
#  (b' j', b'ust'),
#  (b' fl', b'ow'),
#  (b' f', b'ood'),
#  (b' l', b'ist'),
#  (b' did', b'n'),
#  (b' animal', b's'),
#  (b' h', b'ig'),
#  (b'p', b'l'),
#  (b' ne', b'ar'),
#  (b' wa', b't'),
#  (b' ', b'ide'),
#  (b' t', b'ry'),
#  (b'c', b'hed'),
#  (b' sk', b'y'),
#  (b'in', b'e'),
#  (b' s', b'n'),
#  (b'v', b'ing'),
#  (b' f', b'i'),
#  (b'r', b'om'),
#  (b' u', b's'),
#  (b' ide', b'a'),
#  (b' b', b'etter'),
#  (b' A', b'my'),
#  (b' b', b'ug'),
#  (b' he', b'ard'),
#  (b'g', b'ry'),
#  (b' it', b's'),
#  (b' t', b'w'),
#  (b' l', b'et'),
#  (b'p', b'ec'),
#  (b'at', b'e'),
#  (b'ab', b'le'),
#  (b'f', b'f'),
#  (b' ', b'en'),
#  (b' care', b'ful'),
#  (b' sh', b'are'),
#  (b'e', b'x'),
#  (b' ', b'if'),
#  (b'Th', b'ank'),
#  (b'M', b'om'),
#  (b' f', b'ly'),
#  (b' st', b'or'),
#  (b'i', b'al'),
#  (b' f', b'lew'),
#  (b'm', b'ore'),
#  (b' any', b'more'),
#  (b' T', b'h'),
#  (b' sp', b'ec'),
#  (b' spec', b'ial'),
#  (b'i', b'on'),
#  (b' c', b'om'),
#  (b' lot', b's'),
#  (b' ne', b'ver'),
#  (b' b', b'y'),
#  (b'l', b'f'),
#  (b're', b'am'),
#  (b' d', b'an'),
#  (b' b', b'u'),
#  (b' f', b'o'),
#  (b' w', b'ind'),
#  (b' d', b'on'),
#  (b' t', b'al'),
#  (b' cle', b'an'),
#  (b'or', b't'),
#  (b' g', b'r'),
#  (b' lo', b've'),
#  (b'r', b'm'),
#  (b'b', b'er'),
#  (b' e', b'nd'),
#  (b'\n', b'\n'),
#  (b' The', b'n'),
#  (b'op', b'le'),
#  (b' e', b'ven'),
#  (b' m', b'ag'),
#  (b' h', b'ard'),
#  (b' sh', b'iny'),
#  (b'udd', b'en'),
#  (b' f', b'ore'),
#  (b' o', b'ver'),
#  (b' c', b'ake'),
#  (b'a', b'k'),
#  (b' b', b'ook'),
#  (b' co', b'l'),
#  (b' t', b'urn'),
#  (b' f', b'am'),
#  (b' b', b'ad'),
#  (b' sa', b'fe'),
#  (b' a', b'fter'),
#  (b'ad', b'y'),
#  (b' A', b'nna'),
#  (b'udden', b'ly'),
#  (b' pe', b'ople'),
#  (b' pr', b'oud'),
#  (b' E', b'very'),
#  (b' surpr', b'ised'),
#  (b'pec', b'ted'),
#  (b'L', b'et'),
#  (b' hig', b'h'),
#  (b' c', b'u'),
#  (b' h', b'urt'),
#  (b' c', b'ome'),
#  (b'im', b'b'),
#  (b'ard', b'en'),
#  (b' do', b'or'),
#  (b' g', b'arden'),
#  (b'b', b'b'),
#  (b' g', b'round'),
#  (b' op', b'ened'),
#  (b' pic', b'ked'),
#  (b' l', b'oud'),
#  (b' cl', b'imb'),
#  (b'ex', b'pected'),
#  (b' un', b'expected'),
#  (b' g', b'l'),
#  (b' c', b'he'),
#  (b'il', b'd'),
#  (b' ', b'im'),
#  (b'A', b's'),
#  (b' g', b'ive'),
#  (b' wa', b'y'),
#  (b'a', b'il'),
#  (b"'", b'm'),
#  (b' than', b'ked'),
#  (b' col', b'or'),
#  (b' bl', b'ue'),
#  (b' st', b'ill'),
#  (b' e', b'ver'),
#  (b' hug', b'ged'),
#  (b' F', b'rom'),
#  (b' c', b'all'),
#  (b' f', b'ar'),
#  (b'i', b'p'),
#  (b' H', b'er'),
#  (b' S', b'ara'),
#  (b' W', b'hen'),
#  (b'N', b'o'),
#  (b' of', b'f'),
#  (b' mag', b'ic'),
#  (b'i', b'z'),
#  (b'oug', b'h'),
#  (b'ag', b'e'),
#  (b'um', b'my'),
#  (b' ', b'K'),
#  (b' jump', b'ed'),
#  (b' sh', b'ould'),
#  (b' fam', b'ily'),
#  (b' p', b'ar'),
#  (b'oo', b'l'),
#  (b' k', b'id'),
#  (b' sm', b'ile'),
#  (b'he', b's'),
#  (b'u', b'ff'),
#  (b' pl', b'ace'),
#  (b'k', b'ay'),
#  (b' wal', b'k'),
#  (b' n', b'ow'),
#  (b'c', b't'),
#  (b' I', b'n'),
#  (b' gre', b'at'),
#  (b'e', b'm'),
#  (b't', b'ure'),
#  (b' ', b'qu'),
#  (b'le', b's'),
#  (b' str', b'ong'),
#  (b' st', b'ay'),
#  (b' u', b'nt'),
#  (b' st', b'o'),
#  (b'a', b'ut'),
#  (b' fore', b'st'),
#  (b'an', b'e'),
#  (b' b', b'ra'),
#  (b'itt', b'y'),
#  (b' ', b'P'),
#  (b' fr', b'og'),
#  (b' br', b'o'),
#  (b' unt', b'il'),
#  (b'o', b'on'),
#  (b' be', b'aut'),
#  (b'd', b'y'),
#  (b' s', b'qu'),
#  (b' st', b'ick'),
#  (b'x', b't'),
#  (b' ne', b'xt'),
#  (b' bo', b'at'),
#  (b'le', b'ase'),
#  (b'n', b'ing'),
#  (b' happ', b'ily'),
#  (b' list', b'en'),
#  (b'a', b'king'),
#  (b' kid', b's'),
#  (b' t', b'ra'),
#  (b'i', b'es'),
#  (b'i', b'ful'),
#  (b' beaut', b'iful'),
#  (b' a', b'pp'),
#  (b't', b'h'),
#  (b' help', b'ed'),
#  (b' d', b'ra'),
#  (b' show', b'ed'),
#  (b' clo', b's'),
#  (b'b', b'e'),
#  (b' im', b'p'),
#  (b' stor', b'y'),
#  (b'un', b'ny'),
#  (b'o', b'y'),
#  (b' wh', b'ile'),
#  (b' tow', b'n'),
#  (b're', b'l'),
#  (b'p', b't'),
#  (b' r', b'ain'),
#  (b're', b'ss'),
#  (b' pic', b'ture'),
#  (b' be', b'ing'),
#  (b' re', b'm'),
#  (b' every', b'one'),
#  (b'I', b't'),
#  (b'ar', b'y'),
#  (b're', b'e'),
#  (b' m', b'or'),
#  (b' ha', b't'),
#  (b' call', b'ed'),
#  (b' m', b'et'),
#  (b' sto', b'pped'),
#  (b' a', b'd'),
#  (b' g', b'ame'),
#  (b'N', b'ow'),
#  (b'H', b'e'),
#  (b'C', b'an'),
#  (b' an', b'gry'),
#  (b'g', b'er'),
#  (b'uff', b'y'),
#  (b' op', b'en'),
#  (b' w', b'o'),
#  (b' tr', b'uck'),
#  (b' ke', b'ep'),
#  (b' so', b'ft'),
#  (b'W', b'hen'),
#  (b' c', b'ry'),
#  (b' y', b'ummy'),
#  (b' lo', b'st'),
#  (b' b', b'ed'),
#  (b' L', b'et'),
#  (b' S', b'ally'),
#  (b' wa', b'rm'),
#  (b'b', b'y'),
#  (b'v', b'ent'),
#  (b' bra', b've'),
#  (b' m', b'ouse'),
#  (b' W', b'h'),
#  (b' at', b'e'),
#  (b' K', b'itty'),
#  (b'is', b'hed'),
#  (b' d', b'e'),
#  (b'f', b'ore'),
#  (b' do', b'll'),
#  (b's', b'o'),
#  (b' could', b'n'),
#  (b' wat', b'ch'),
#  (b' le', b'ave'),
#  (b' al', b'so'),
#  (b'dd', b'ed'),
#  (b' f', b'ell'),
#  (b' gre', b'en'),
#  (b' fa', b'ce'),
#  (b' tw', b'o'),
#  (b'g', b'an'),
#  (b'is', b's'),
#  (b' flow', b'ers'),
#  (b'b', b'it'),
#  (b'Wh', b'at'),
#  (b' ', b'R'),
#  (b'b', b'le'),
#  (b' no', b'ise'),
#  (b'ab', b'bit'),
#  (b'ir', b'st'),
#  (b'ow', b'l'),
#  (b' w', b'here'),
#  (b'a', b'z'),
#  (b'o', b'ck'),
#  (b' so', b'on'),
#  (b'se', b'lf'),
#  (b' sl', b'ide'),
#  (b' r', b'abbit'),
#  (b' ho', b'le'),
#  (b'l', b'uffy'),
#  (b' be', b'fore'),
#  (b'ir', b'rel'),
#  (b' p', b'us'),
#  (b'ir', b'ed'),
#  (b' sa', b't'),
#  (b'ill', b'y'),
#  (b' he', b'ar'),
#  (b' u', b'se'),
#  (b'\xe2\x80', b'\x9d'),
#  (b'H', b'i'),
#  (b' p', b'a'),
#  (b' ke', b'pt'),
#  (b'\xe2\x80', b'\x9c'),
#  (b'Th', b'at'),
#  (b' squ', b'irrel'),
#  (b'e', b'ar'),
#  (b'The', b'n'),
#  (b'm', b'a'),
#  (b' no', b'dded'),
#  (b' ex', b'pl'),
#  (b' st', b'ore'),
#  (b' c', b'ook'),
#  (b' hand', b's'),
#  (b'L', b'ook'),
#  (b' bird', b's'),
#  (b' p', b'ain'),
#  (b' go', b'ing'),
#  (b' fun', b'ny'),
#  (b' ha', b'ving'),
#  (b'd', b'ay'),
#  (b' s', b'ing'),
#  (b'ay', b'be'),
#  (b'u', b'ch'),
#  (b' e', b'y'),
#  (b'a', b'ug'),
#  (b' cat', b'ch'),
#  (b'aug', b'ht'),
#  (b' C', b'an'),
#  (b' F', b'luffy'),
#  (b'u', b'it'),
#  (b' y', b'ell'),
#  (b' th', b'ink'),
#  (b'le', b'ep'),
#  (b' c', b'ra'),
#  (b' f', b'in'),
#  (b'B', b'en'),
#  (b' b', b're'),
#  (b' fi', b'x'),
#  (b' t', b'ired'),
#  (b' b', b'unny'),
#  (b' us', b'ed'),
#  (b' loo', b'king'),
#  (b' b', b'us'),
#  (b'an', b'ge'),
#  (b'a', b'ir'),
#  (b' wor', b'k'),
#  (b' w', b'r'),
#  (b' ', b'our'),
#  (b' p', b'ull'),
#  (b'W', b'e'),
#  (b' th', b'r'),
#  (b't', b'hing'),
#  (b' ', b'Now'),
#  (b' wa', b'it'),
#  (b' k', b'it'),
#  (b' s', b'ound'),
#  (b't', b'ing'),
#  (b' j', b'o'),
#  (b' ha', b's'),
#  (b' ', b'G'),
#  (b' me', b'an'),
#  (b' po', b'nd'),
#  (b'em', b'ber'),
#  (b' be', b'h'),
#  (b' d', b'r'),
#  (b' sun', b'ny'),
#  (b'l', b'ed'),
#  (b' other', b's'),
#  (b' as', b'k'),
#  (b'n', b'g'),
#  (b'c', b'hen'),
#  (b' kit', b'chen'),
#  (b' tal', b'k'),
#  (b' fl', b'o'),
#  (b' d', b'if'),
#  (b're', b'w'),
#  (b' p', b'ie'),
#  (b' J', b'o'),
#  (b' he', b'ad'),
#  (b' re', b'al'),
#  (b' f', b'irst'),
#  (b' t', b'ri'),
#  (b' mom', b'my'),
#  (b' ey', b'es'),
#  (b'ell', b'o'),
#  (b' imp', b'ort'),
#  (b'H', b'ello'),
#  (b' fa', b'v'),
#  (b'at', b'h'),
#  (b'j', b'oy'),
#  (b' ', b'z'),
#  (b' rem', b'ember'),
#  (b' r', b'ight'),
#  (b' flow', b'er'),
#  (b' c', b'on'),
#  (b' m', b'ess'),
#  (b' par', b'ty'),
#  (b' co', b'ld'),
#  (b' D', b'o'),
#  (b' v', b'o'),
#  (b' sw', b'e'),
#  (b'i', b'ous'),
#  (b' sa', b'nd'),
#  (b' ', b'\xe2\x80\x9c'),
#  (b'a', b'c'),
#  (b'or', b'n'),
#  (b' r', b'ace'),
#  (b' cu', b'ri'),
#  (b'im', b'es'),
#  (b' import', b'ant'),
#  (b' d', b'uck'),
#  (b' mor', b'al'),
#  (b' sh', b'ared'),
#  (b'z', b'y'),
#  (b'ou', b'nt'),
#  (b' J', b'ack'),
#  (b' ', b'ice'),
#  (b' o', b'kay'),
#  (b' ad', b'vent'),
#  (b' wor', b'ked'),
#  (b'll', b'ow'),
#  (b'A', b't'),
#  (b' en', b'joy'),
#  (b' d', b'ress'),
#  (b' br', b'ight'),
#  (b' m', b'aking'),
#  (b' curi', b'ous'),
#  (b' ', b'own'),
#  (b' t', b'all'),
#  (b' d', b'ir'),
#  (b' h', b'op'),
#  (b're', b'ed'),
#  (b' h', b'id'),
#  (b' fav', b'or'),
#  (b' ', b'ri'),
#  (b'h', b'n'),
#  (b' s', b'leep'),
#  (b' d', b'is'),
#  (b'W', b'ow'),
#  (b' favor', b'ite'),
#  (b' th', b'ing'),
#  (b' be', b'gan'),
#  (b' m', b'on'),
#  (b' b', b'ag'),
#  (b' h', b'ill'),
#  (b'D', b'on'),
#  (b' cl', b'a'),
#  (b' dra', b'w'),
#  (b' re', b'st'),
#  (b' he', b're'),
#  (b' y', b'ard'),
#  (b' t', b'ell'),
#  (b' F', b'in'),
#  (b'st', b'er'),
#  (b' wat', b'ched'),
#  (b'q', b'ue'),
#  (b' fo', b'llow'),
#  (b' mo', b've'),
#  (b' be', b'l'),
#  (b'ec', b't'),
#  ...]

# %%
vocab # I need the reversed vocab, from tuple of byte to indices
# Out:
# {0: b'\x00',
#  1: b'\x01',
#  2: b'\x02',
#  3: b'\x03',
#  4: b'\x04',
#  5: b'\x05',
#  6: b'\x06',
#  7: b'\x07',
#  8: b'\x08',
#  9: b'\t',
#  10: b'\n',
#  11: b'\x0b',
#  12: b'\x0c',
#  13: b'\r',
#  14: b'\x0e',
#  15: b'\x0f',
#  16: b'\x10',
#  17: b'\x11',
#  18: b'\x12',
#  19: b'\x13',
#  20: b'\x14',
#  21: b'\x15',
#  22: b'\x16',
#  23: b'\x17',
#  24: b'\x18',
#  25: b'\x19',
#  26: b'\x1a',
#  27: b'\x1b',
#  28: b'\x1c',
#  29: b'\x1d',
#  30: b'\x1e',
#  31: b'\x1f',
#  32: b' ',
#  33: b'!',
#  34: b'"',
#  35: b'#',
#  36: b'$',
#  37: b'%',
#  38: b'&',
#  39: b"'",
#  40: b'(',
#  41: b')',
#  42: b'*',
#  43: b'+',
#  44: b',',
#  45: b'-',
#  46: b'.',
#  47: b'/',
#  48: b'0',
#  49: b'1',
#  50: b'2',
#  51: b'3',
#  52: b'4',
#  53: b'5',
#  54: b'6',
#  55: b'7',
#  56: b'8',
#  57: b'9',
#  58: b':',
#  59: b';',
#  60: b'<',
#  61: b'=',
#  62: b'>',
#  63: b'?',
#  64: b'@',
#  65: b'A',
#  66: b'B',
#  67: b'C',
#  68: b'D',
#  69: b'E',
#  70: b'F',
#  71: b'G',
#  72: b'H',
#  73: b'I',
#  74: b'J',
#  75: b'K',
#  76: b'L',
#  77: b'M',
#  78: b'N',
#  79: b'O',
#  80: b'P',
#  81: b'Q',
#  82: b'R',
#  83: b'S',
#  84: b'T',
#  85: b'U',
#  86: b'V',
#  87: b'W',
#  88: b'X',
#  89: b'Y',
#  90: b'Z',
#  91: b'[',
#  92: b'\\',
#  93: b']',
#  94: b'^',
#  95: b'_',
#  96: b'`',
#  97: b'a',
#  98: b'b',
#  99: b'c',
#  100: b'd',
#  101: b'e',
#  102: b'f',
#  103: b'g',
#  104: b'h',
#  105: b'i',
#  106: b'j',
#  107: b'k',
#  108: b'l',
#  109: b'm',
#  110: b'n',
#  111: b'o',
#  112: b'p',
#  113: b'q',
#  114: b'r',
#  115: b's',
#  116: b't',
#  117: b'u',
#  118: b'v',
#  119: b'w',
#  120: b'x',
#  121: b'y',
#  122: b'z',
#  123: b'{',
#  124: b'|',
#  125: b'}',
#  126: b'~',
#  127: b'\x7f',
#  128: b'\x80',
#  129: b'\x81',
#  130: b'\x82',
#  131: b'\x83',
#  132: b'\x84',
#  133: b'\x85',
#  134: b'\x86',
#  135: b'\x87',
#  136: b'\x88',
#  137: b'\x89',
#  138: b'\x8a',
#  139: b'\x8b',
#  140: b'\x8c',
#  141: b'\x8d',
#  142: b'\x8e',
#  143: b'\x8f',
#  144: b'\x90',
#  145: b'\x91',
#  146: b'\x92',
#  147: b'\x93',
#  148: b'\x94',
#  149: b'\x95',
#  150: b'\x96',
#  151: b'\x97',
#  152: b'\x98',
#  153: b'\x99',
#  154: b'\x9a',
#  155: b'\x9b',
#  156: b'\x9c',
#  157: b'\x9d',
#  158: b'\x9e',
#  159: b'\x9f',
#  160: b'\xa0',
#  161: b'\xa1',
#  162: b'\xa2',
#  163: b'\xa3',
#  164: b'\xa4',
#  165: b'\xa5',
#  166: b'\xa6',
#  167: b'\xa7',
#  168: b'\xa8',
#  169: b'\xa9',
#  170: b'\xaa',
#  171: b'\xab',
#  172: b'\xac',
#  173: b'\xad',
#  174: b'\xae',
#  175: b'\xaf',
#  176: b'\xb0',
#  177: b'\xb1',
#  178: b'\xb2',
#  179: b'\xb3',
#  180: b'\xb4',
#  181: b'\xb5',
#  182: b'\xb6',
#  183: b'\xb7',
#  184: b'\xb8',
#  185: b'\xb9',
#  186: b'\xba',
#  187: b'\xbb',
#  188: b'\xbc',
#  189: b'\xbd',
#  190: b'\xbe',
#  191: b'\xbf',
#  192: b'\xc0',
#  193: b'\xc1',
#  194: b'\xc2',
#  195: b'\xc3',
#  196: b'\xc4',
#  197: b'\xc5',
#  198: b'\xc6',
#  199: b'\xc7',
#  200: b'\xc8',
#  201: b'\xc9',
#  202: b'\xca',
#  203: b'\xcb',
#  204: b'\xcc',
#  205: b'\xcd',
#  206: b'\xce',
#  207: b'\xcf',
#  208: b'\xd0',
#  209: b'\xd1',
#  210: b'\xd2',
#  211: b'\xd3',
#  212: b'\xd4',
#  213: b'\xd5',
#  214: b'\xd6',
#  215: b'\xd7',
#  216: b'\xd8',
#  217: b'\xd9',
#  218: b'\xda',
#  219: b'\xdb',
#  220: b'\xdc',
#  221: b'\xdd',
#  222: b'\xde',
#  223: b'\xdf',
#  224: b'\xe0',
#  225: b'\xe1',
#  226: b'\xe2',
#  227: b'\xe3',
#  228: b'\xe4',
#  229: b'\xe5',
#  230: b'\xe6',
#  231: b'\xe7',
#  232: b'\xe8',
#  233: b'\xe9',
#  234: b'\xea',
#  235: b'\xeb',
#  236: b'\xec',
#  237: b'\xed',
#  238: b'\xee',
#  239: b'\xef',
#  240: b'\xf0',
#  241: b'\xf1',
#  242: b'\xf2',
#  243: b'\xf3',
#  244: b'\xf4',
#  245: b'\xf5',
#  246: b'\xf6',
#  247: b'\xf7',
#  248: b'\xf8',
#  249: b'\xf9',
#  250: b'\xfa',
#  251: b'\xfb',
#  252: b'\xfc',
#  253: b'\xfd',
#  254: b'\xfe',
#  255: b'\xff',
#  256: b' t',
#  257: b'he',
#  258: b' a',
#  259: b' s',
#  260: b' w',
#  261: b'nd',
#  262: b' the',
#  263: b'ed',
#  264: b' b',
#  265: b' to',
#  266: b' and',
#  267: b' h',
#  268: b' f',
#  269: b'in',
#  270: b' T',
#  271: b' wa',
#  272: b're',
#  273: b'it',
#  274: b'ou',
#  275: b' l',
#  276: b' d',
#  277: b' c',
#  278: b' p',
#  279: b'ay',
#  280: b' m',
#  281: b'er',
#  282: b' was',
#  283: b'om',
#  284: b' The',
#  285: b' he',
#  286: b'is',
#  287: b'ar',
#  288: b' n',
#  289: b'im',
#  290: b'on',
#  291: b' sa',
#  292: b'id',
#  293: b'll',
#  294: b' ha',
#  295: b' g',
#  296: b'at',
#  297: b' S',
#  298: b'ing',
#  299: b'ot',
#  300: b'en',
#  301: b'an',
#  302: b'le',
#  303: b'or',
#  304: b'ir',
#  305: b'am',
#  306: b'et',
#  307: b' H',
#  308: b' it',
#  309: b' th',
#  310: b'ig',
#  311: b' They',
#  312: b' in',
#  313: b'il',
#  314: b' pl',
#  315: b' He',
#  316: b' "',
#  317: b'ow',
#  318: b'ver',
#  319: b'ri',
#  320: b'ut',
#  321: b' be',
#  322: b' u',
#  323: b' said',
#  324: b' play',
#  325: b'ith',
#  326: b' day',
#  327: b' with',
#  328: b'pp',
#  329: b'On',
#  330: b' o',
#  331: b' y',
#  332: b'oo',
#  333: b'ked',
#  334: b' r',
#  335: b' her',
#  336: b'ce',
#  337: b' I',
#  338: b' She',
#  339: b'ld',
#  340: b' Tim',
#  341: b' his',
#  342: b' st',
#  343: b'ke',
#  344: b' e',
#  345: b' big',
#  346: b'nt',
#  347: b'ck',
#  348: b' you',
#  349: b'very',
#  350: b'st',
#  351: b've',
#  352: b'end',
#  353: b' on',
#  354: b'un',
#  355: b' happ',
#  356: b'riend',
#  357: b' friend',
#  358: b'all',
#  359: b'ily',
#  360: b' L',
#  361: b' they',
#  362: b' we',
#  363: b' had',
#  364: b' not',
#  365: b' li',
#  366: b' up',
#  367: b'her',
#  368: b' want',
#  369: b' of',
#  370: b'ad',
#  371: b'itt',
#  372: b'se',
#  373: b' B',
#  374: b' do',
#  375: b' happy',
#  376: b'ent',
#  377: b' very',
#  378: b' M',
#  379: b'es',
#  380: b' that',
#  381: b' saw',
#  382: b'One',
#  383: b"'s",
#  384: b'ould',
#  385: b' mom',
#  386: b' for',
#  387: b' sh',
#  388: b'ittle',
#  389: b' little',
#  390: b' so',
#  391: b' she',
#  392: b'ch',
#  393: b'ime',
#  394: b' ne',
#  395: b' nam',
#  396: b'."',
#  397: b' time',
#  398: b' k',
#  399: b'ound',
#  400: b' there',
#  401: b' named',
#  402: b' sm',
#  403: b' bo',
#  404: b' were',
#  405: b' Lily',
#  406: b' wanted',
#  407: b' but',
#  408: b'out',
#  409: b'The',
#  410: b' friends',
#  411: b'ved',
#  412: b'!"',
#  413: b'ht',
#  414: b' Tom',
#  415: b'ird',
#  416: b'el',
#  417: b' bird',
#  418: b'al',
#  419: b' an',
#  420: b'ake',
#  421: b' too',
#  422: b'ome',
#  423: b' It',
#  424: b'ug',
#  425: b'ide',
#  426: b' went',
#  427: b' wh',
#  428: b' hel',
#  429: b'Once',
#  430: b' is',
#  431: b' all',
#  432: b' help',
#  433: b'ue',
#  434: b' loo',
#  435: b' lo',
#  436: b'ter',
#  437: b' A',
#  438: b' upon',
#  439: b'ry',
#  440: b'ore',
#  441: b'ind',
#  442: b' fun',
#  443: b'get',
#  444: b' toy',
#  445: b'ill',
#  446: b'ame',
#  447: b' as',
#  448: b' at',
#  449: b'ra',
#  450: b' j',
#  451: b' did',
#  452: b'gether',
#  453: b' re',
#  454: b'ur',
#  455: b' se',
#  456: b' together',
#  457: b'ack',
#  458: b' cat',
#  459: b'ly',
#  460: b' tre',
#  461: b'ood',
#  462: b'ic',
#  463: b'ted',
#  464: b' dog',
#  465: b' could',
#  466: b' can',
#  467: b' their',
#  468: b'ard',
#  469: b'ec',
#  470: b'ark',
#  471: b' gir',
#  472: b' played',
#  473: b' him',
#  474: b' ball',
#  475: b'?"',
#  476: b' girl',
#  477: b'way',
#  478: b' ro',
#  479: b' go',
#  480: b'hed',
#  481: b'my',
#  482: b' are',
#  483: b' out',
#  484: b' le',
#  485: b' fr',
#  486: b'ain',
#  487: b' kn',
#  488: b'hen',
#  489: b' them',
#  490: b'um',
#  491: b"'t",
#  492: b'ax',
#  493: b' sad',
#  494: b'ul',
#  495: b' boy',
#  496: b' tree',
#  497: b'other',
#  498: b' have',
#  499: b' man',
#  500: b' cl',
#  501: b' loved',
#  502: b' looked',
#  503: b'oug',
#  504: b' found',
#  505: b' sp',
#  506: b' star',
#  507: b' Sue',
#  508: b'one',
#  509: b'hing',
#  510: b' sc',
#  511: b' back',
#  512: b'own',
#  513: b' Max',
#  514: b'are',
#  515: b' like',
#  516: b'ful',
#  517: b'side',
#  518: b' me',
#  519: b' bec',
#  520: b' park',
#  521: b'ight',
#  522: b'ong',
#  523: b' car',
#  524: b'op',
#  525: b'elt',
#  526: b' One',
#  527: b' liked',
#  528: b' would',
#  529: b' make',
#  530: b'round',
#  531: b' la',
#  532: b' fa',
#  533: b' felt',
#  534: b'You',
#  535: b' W',
#  536: b'ell',
#  537: b' see',
#  538: b' But',
#  539: b'omet',
#  540: b' asked',
#  541: b'ag',
#  542: b' new',
#  543: b' no',
#  544: b'ice',
#  545: b' Sam',
#  546: b'ouse',
#  547: b' started',
#  548: b'ared',
#  549: b' came',
#  550: b' Ben',
#  551: b' al',
#  552: b' other',
#  553: b'ought',
#  554: b'iled',
#  555: b' somet',
#  556: b' ag',
#  557: b' good',
#  558: b' small',
#  559: b'ss',
#  560: b' br',
#  561: b' smiled',
#  562: b' say',
#  563: b'ried',
#  564: b'ade',
#  565: b'ings',
#  566: b'ob',
#  567: b'pot',
#  568: b' wor',
#  569: b' find',
#  570: b' ex',
#  571: b'ia',
#  572: b' away',
#  573: b'ty',
#  574: b' put',
#  575: b' what',
#  576: b' something',
#  577: b' co',
#  578: b' from',
#  579: b' made',
#  580: b' thought',
#  581: b'ened',
#  582: b' home',
#  583: b' playing',
#  584: b'ook',
#  585: b' every',
#  586: b' wal',
#  587: b' mu',
#  588: b'uc',
#  589: b'ach',
#  590: b'arn',
#  591: b' Spot',
#  592: b' ran',
#  593: b'ile',
#  594: b' F',
#  595: b'ie',
#  596: b' J',
#  597: b'ave',
#  598: b' again',
#  599: b' some',
#  600: b' laug',
#  601: b'dd',
#  602: b' house',
#  603: b' down',
#  604: b' fl',
#  605: b'king',
#  606: b' took',
#  607: b' scared',
#  608: b' pr',
#  609: b'ny',
#  610: b'ure',
#  611: b' toys',
#  612: b' learn',
#  613: b' You',
#  614: b'if',
#  615: b' will',
#  616: b' box',
#  617: b'ick',
#  618: b'ret',
#  619: b'ab',
#  620: b'ep',
#  621: b' my',
#  622: b' around',
#  623: b' things',
#  624: b' your',
#  625: b'oud',
#  626: b' bl',
#  627: b'uck',
#  628: b' when',
#  629: b'ish',
#  630: b' lived',
#  631: b' fe',
#  632: b' then',
#  633: b' sun',
#  634: b'as',
#  635: b' sw',
#  636: b',"',
#  637: b' ch',
#  638: b'us',
#  639: b'pped',
#  640: b' ab',
#  641: b' Mia',
#  642: b'ank',
#  643: b' get',
#  644: b'ucy',
#  645: b'Tim',
#  646: b'ump',
#  647: b'Th',
#  648: b' lot',
#  649: b'ist',
#  650: b'oth',
#  651: b' tried',
#  652: b'ap',
#  653: b' know',
#  654: b' says',
#  655: b' got',
#  656: b'ited',
#  657: b' who',
#  658: b' kne',
#  659: b'ust',
#  660: b' many',
#  661: b'nder',
#  662: b' int',
#  663: b' about',
#  664: b'Lily',
#  665: b' pret',
#  666: b' dec',
#  667: b' any',
#  668: b' red',
#  669: b' D',
#  670: b'ive',
#  671: b' knew',
#  672: b'ace',
#  673: b'ous',
#  674: b' more',
#  675: b'ise',
#  676: b' care',
#  677: b'ally',
#  678: b' pic',
#  679: b'au',
#  680: b'qu',
#  681: b' hug',
#  682: b' Lucy',
#  683: b' learned',
#  684: b' po',
#  685: b' water',
#  686: b'fter',
#  687: b' v',
#  688: b' became',
#  689: b' best',
#  690: b'ause',
#  691: b' op',
#  692: b' gre',
#  693: b' exc',
#  694: b'urp',
#  695: b'ways',
#  696: b'\xe2\x80',
#  697: b' outside',
#  698: b' laughed',
#  699: b' look',
#  700: b' always',
#  701: b' decid',
#  702: b' show',
#  703: b' un',
#  704: b'ant',
#  705: b' Bob',
#  706: b' room',
#  707: b'fe',
#  708: b' decided',
#  709: b' ho',
#  710: b' because',
#  711: b' So',
#  712: b' into',
#  713: b' eat',
#  714: b'ite',
#  715: b' jump',
#  716: b' And',
#  717: b' pe',
#  718: b' both',
#  719: b'ers',
#  720: b' Mom',
#  721: b' dad',
#  722: b'They',
#  723: b'udd',
#  724: b' ke',
#  725: b' one',
#  726: b'nn',
#  727: b' this',
#  728: b' excited',
#  729: b' fast',
#  730: b' nice',
#  731: b' E',
#  732: b' feel',
#  733: b'Tom',
#  734: b'Yes',
#  735: b' run',
#  736: b' long',
#  737: b' told',
#  738: b' sk',
#  739: b' am',
#  740: b'urpr',
#  741: b'our',
#  742: b' inside',
#  743: b'ull',
#  744: b' tr',
#  745: b' surpr',
#  746: b' mo',
#  747: b'ink',
#  748: b' pretty',
#  749: b'iny',
#  750: b' sor',
#  751: b'Wh',
#  752: b' take',
#  753: b'og',
#  754: b' sl',
#  755: b' each',
#  756: b' gave',
#  757: b' much',
#  758: b' gra',
#  759: b'lew',
#  760: b'nna',
#  761: b' rock',
#  762: b' how',
#  763: b' str',
#  764: b'ara',
#  765: b'imal',
#  766: b' animal',
#  767: b'ged',
#  768: b' need',
#  769: b' than',
#  770: b'But',
#  771: b'ven',
#  772: b'etter',
#  773: b' tow',
#  774: b' or',
#  775: b' C',
#  776: b' under',
#  777: b'ess',
#  778: b' old',
#  779: b' sorry',
#  780: b'ge',
#  781: b'ised',
#  782: b'ro',
#  783: b'urt',
#  784: b' cle',
#  785: b' fish',
#  786: b' walked',
#  787: b' clo',
#  788: b'and',
#  789: b' bear',
#  790: b'ft',
#  791: b'ase',
#  792: b'ast',
#  793: b' hand',
#  794: b'urn',
#  795: b' We',
#  796: b' kind',
#  797: b' His',
#  798: b' te',
#  799: b'here',
#  800: b' happened',
#  801: b' just',
#  802: b' flow',
#  803: b' food',
#  804: b' list',
#  805: b' didn',
#  806: b' animals',
#  807: b' hig',
#  808: b'pl',
#  809: b' near',
#  810: b' wat',
#  811: b' ide',
#  812: b' try',
#  813: b'ched',
#  814: b' sky',
#  815: b'ine',
#  816: b' sn',
#  817: b'ving',
#  818: b' fi',
#  819: b'rom',
#  820: b' us',
#  821: b' idea',
#  822: b' better',
#  823: b' Amy',
#  824: b' bug',
#  825: b' heard',
#  826: b'gry',
#  827: b' its',
#  828: b' tw',
#  829: b' let',
#  830: b'pec',
#  831: b'ate',
#  832: b'able',
#  833: b'ff',
#  834: b' en',
#  835: b' careful',
#  836: b' share',
#  837: b'ex',
#  838: b' if',
#  839: b'Thank',
#  840: b'Mom',
#  841: b' fly',
#  842: b' stor',
#  843: b'ial',
#  844: b' flew',
#  845: b'more',
#  846: b' anymore',
#  847: b' Th',
#  848: b' spec',
#  849: b' special',
#  850: b'ion',
#  851: b' com',
#  852: b' lots',
#  853: b' never',
#  854: b' by',
#  855: b'lf',
#  856: b'ream',
#  857: b' dan',
#  858: b' bu',
#  859: b' fo',
#  860: b' wind',
#  861: b' don',
#  862: b' tal',
#  863: b' clean',
#  864: b'ort',
#  865: b' gr',
#  866: b' love',
#  867: b'rm',
#  868: b'ber',
#  869: b' end',
#  870: b'\n\n',
#  871: b' Then',
#  872: b'ople',
#  873: b' even',
#  874: b' mag',
#  875: b' hard',
#  876: b' shiny',
#  877: b'udden',
#  878: b' fore',
#  879: b' over',
#  880: b' cake',
#  881: b'ak',
#  882: b' book',
#  883: b' col',
#  884: b' turn',
#  885: b' fam',
#  886: b' bad',
#  887: b' safe',
#  888: b' after',
#  889: b'ady',
#  890: b' Anna',
#  891: b'uddenly',
#  892: b' people',
#  893: b' proud',
#  894: b' Every',
#  895: b' surprised',
#  896: b'pected',
#  897: b'Let',
#  898: b' high',
#  899: b' cu',
#  900: b' hurt',
#  901: b' come',
#  902: b'imb',
#  903: b'arden',
#  904: b' door',
#  905: b' garden',
#  906: b'bb',
#  907: b' ground',
#  908: b' opened',
#  909: b' picked',
#  910: b' loud',
#  911: b' climb',
#  912: b'expected',
#  913: b' unexpected',
#  914: b' gl',
#  915: b' che',
#  916: b'ild',
#  917: b' im',
#  918: b'As',
#  919: b' give',
#  920: b' way',
#  921: b'ail',
#  922: b"'m",
#  923: b' thanked',
#  924: b' color',
#  925: b' blue',
#  926: b' still',
#  927: b' ever',
#  928: b' hugged',
#  929: b' From',
#  930: b' call',
#  931: b' far',
#  932: b'ip',
#  933: b' Her',
#  934: b' Sara',
#  935: b' When',
#  936: b'No',
#  937: b' off',
#  938: b' magic',
#  939: b'iz',
#  940: b'ough',
#  941: b'age',
#  942: b'ummy',
#  943: b' K',
#  944: b' jumped',
#  945: b' should',
#  946: b' family',
#  947: b' par',
#  948: b'ool',
#  949: b' kid',
#  950: b' smile',
#  951: b'hes',
#  952: b'uff',
#  953: b' place',
#  954: b'kay',
#  955: b' walk',
#  956: b' now',
#  957: b'ct',
#  958: b' In',
#  959: b' great',
#  960: b'em',
#  961: b'ture',
#  962: b' qu',
#  963: b'les',
#  964: b' strong',
#  965: b' stay',
#  966: b' unt',
#  967: b' sto',
#  968: b'aut',
#  969: b' forest',
#  970: b'ane',
#  971: b' bra',
#  972: b'itty',
#  973: b' P',
#  974: b' frog',
#  975: b' bro',
#  976: b' until',
#  977: b'oon',
#  978: b' beaut',
#  979: b'dy',
#  980: b' squ',
#  981: b' stick',
#  982: b'xt',
#  983: b' next',
#  984: b' boat',
#  985: b'lease',
#  986: b'ning',
#  987: b' happily',
#  988: b' listen',
#  989: b'aking',
#  990: b' kids',
#  991: b' tra',
#  992: b'ies',
#  993: b'iful',
#  994: b' beautiful',
#  995: b' app',
#  996: b'th',
#  997: b' helped',
#  998: b' dra',
#  999: b' showed',
#  ...}

# %%
reversed_vocab = {v : k for k, v in vocab.items()} #tuple of bytes - > index int
reversed_vocab
# Out:
# {b'\x00': 0,
#  b'\x01': 1,
#  b'\x02': 2,
#  b'\x03': 3,
#  b'\x04': 4,
#  b'\x05': 5,
#  b'\x06': 6,
#  b'\x07': 7,
#  b'\x08': 8,
#  b'\t': 9,
#  b'\n': 10,
#  b'\x0b': 11,
#  b'\x0c': 12,
#  b'\r': 13,
#  b'\x0e': 14,
#  b'\x0f': 15,
#  b'\x10': 16,
#  b'\x11': 17,
#  b'\x12': 18,
#  b'\x13': 19,
#  b'\x14': 20,
#  b'\x15': 21,
#  b'\x16': 22,
#  b'\x17': 23,
#  b'\x18': 24,
#  b'\x19': 25,
#  b'\x1a': 26,
#  b'\x1b': 27,
#  b'\x1c': 28,
#  b'\x1d': 29,
#  b'\x1e': 30,
#  b'\x1f': 31,
#  b' ': 32,
#  b'!': 33,
#  b'"': 34,
#  b'#': 35,
#  b'$': 36,
#  b'%': 37,
#  b'&': 38,
#  b"'": 39,
#  b'(': 40,
#  b')': 41,
#  b'*': 42,
#  b'+': 43,
#  b',': 44,
#  b'-': 45,
#  b'.': 46,
#  b'/': 47,
#  b'0': 48,
#  b'1': 49,
#  b'2': 50,
#  b'3': 51,
#  b'4': 52,
#  b'5': 53,
#  b'6': 54,
#  b'7': 55,
#  b'8': 56,
#  b'9': 57,
#  b':': 58,
#  b';': 59,
#  b'<': 60,
#  b'=': 61,
#  b'>': 62,
#  b'?': 63,
#  b'@': 64,
#  b'A': 65,
#  b'B': 66,
#  b'C': 67,
#  b'D': 68,
#  b'E': 69,
#  b'F': 70,
#  b'G': 71,
#  b'H': 72,
#  b'I': 73,
#  b'J': 74,
#  b'K': 75,
#  b'L': 76,
#  b'M': 77,
#  b'N': 78,
#  b'O': 79,
#  b'P': 80,
#  b'Q': 81,
#  b'R': 82,
#  b'S': 83,
#  b'T': 84,
#  b'U': 85,
#  b'V': 86,
#  b'W': 87,
#  b'X': 88,
#  b'Y': 89,
#  b'Z': 90,
#  b'[': 91,
#  b'\\': 92,
#  b']': 93,
#  b'^': 94,
#  b'_': 95,
#  b'`': 96,
#  b'a': 97,
#  b'b': 98,
#  b'c': 99,
#  b'd': 100,
#  b'e': 101,
#  b'f': 102,
#  b'g': 103,
#  b'h': 104,
#  b'i': 105,
#  b'j': 106,
#  b'k': 107,
#  b'l': 108,
#  b'm': 109,
#  b'n': 110,
#  b'o': 111,
#  b'p': 112,
#  b'q': 113,
#  b'r': 114,
#  b's': 115,
#  b't': 116,
#  b'u': 117,
#  b'v': 118,
#  b'w': 119,
#  b'x': 120,
#  b'y': 121,
#  b'z': 122,
#  b'{': 123,
#  b'|': 124,
#  b'}': 125,
#  b'~': 126,
#  b'\x7f': 127,
#  b'\x80': 128,
#  b'\x81': 129,
#  b'\x82': 130,
#  b'\x83': 131,
#  b'\x84': 132,
#  b'\x85': 133,
#  b'\x86': 134,
#  b'\x87': 135,
#  b'\x88': 136,
#  b'\x89': 137,
#  b'\x8a': 138,
#  b'\x8b': 139,
#  b'\x8c': 140,
#  b'\x8d': 141,
#  b'\x8e': 142,
#  b'\x8f': 143,
#  b'\x90': 144,
#  b'\x91': 145,
#  b'\x92': 146,
#  b'\x93': 147,
#  b'\x94': 148,
#  b'\x95': 149,
#  b'\x96': 150,
#  b'\x97': 151,
#  b'\x98': 152,
#  b'\x99': 153,
#  b'\x9a': 154,
#  b'\x9b': 155,
#  b'\x9c': 156,
#  b'\x9d': 157,
#  b'\x9e': 158,
#  b'\x9f': 159,
#  b'\xa0': 160,
#  b'\xa1': 161,
#  b'\xa2': 162,
#  b'\xa3': 163,
#  b'\xa4': 164,
#  b'\xa5': 165,
#  b'\xa6': 166,
#  b'\xa7': 167,
#  b'\xa8': 168,
#  b'\xa9': 169,
#  b'\xaa': 170,
#  b'\xab': 171,
#  b'\xac': 172,
#  b'\xad': 173,
#  b'\xae': 174,
#  b'\xaf': 175,
#  b'\xb0': 176,
#  b'\xb1': 177,
#  b'\xb2': 178,
#  b'\xb3': 179,
#  b'\xb4': 180,
#  b'\xb5': 181,
#  b'\xb6': 182,
#  b'\xb7': 183,
#  b'\xb8': 184,
#  b'\xb9': 185,
#  b'\xba': 186,
#  b'\xbb': 187,
#  b'\xbc': 188,
#  b'\xbd': 189,
#  b'\xbe': 190,
#  b'\xbf': 191,
#  b'\xc0': 192,
#  b'\xc1': 193,
#  b'\xc2': 194,
#  b'\xc3': 195,
#  b'\xc4': 196,
#  b'\xc5': 197,
#  b'\xc6': 198,
#  b'\xc7': 199,
#  b'\xc8': 200,
#  b'\xc9': 201,
#  b'\xca': 202,
#  b'\xcb': 203,
#  b'\xcc': 204,
#  b'\xcd': 205,
#  b'\xce': 206,
#  b'\xcf': 207,
#  b'\xd0': 208,
#  b'\xd1': 209,
#  b'\xd2': 210,
#  b'\xd3': 211,
#  b'\xd4': 212,
#  b'\xd5': 213,
#  b'\xd6': 214,
#  b'\xd7': 215,
#  b'\xd8': 216,
#  b'\xd9': 217,
#  b'\xda': 218,
#  b'\xdb': 219,
#  b'\xdc': 220,
#  b'\xdd': 221,
#  b'\xde': 222,
#  b'\xdf': 223,
#  b'\xe0': 224,
#  b'\xe1': 225,
#  b'\xe2': 226,
#  b'\xe3': 227,
#  b'\xe4': 228,
#  b'\xe5': 229,
#  b'\xe6': 230,
#  b'\xe7': 231,
#  b'\xe8': 232,
#  b'\xe9': 233,
#  b'\xea': 234,
#  b'\xeb': 235,
#  b'\xec': 236,
#  b'\xed': 237,
#  b'\xee': 238,
#  b'\xef': 239,
#  b'\xf0': 240,
#  b'\xf1': 241,
#  b'\xf2': 242,
#  b'\xf3': 243,
#  b'\xf4': 244,
#  b'\xf5': 245,
#  b'\xf6': 246,
#  b'\xf7': 247,
#  b'\xf8': 248,
#  b'\xf9': 249,
#  b'\xfa': 250,
#  b'\xfb': 251,
#  b'\xfc': 252,
#  b'\xfd': 253,
#  b'\xfe': 254,
#  b'\xff': 255,
#  b' t': 256,
#  b'he': 257,
#  b' a': 258,
#  b' s': 259,
#  b' w': 260,
#  b'nd': 261,
#  b' the': 262,
#  b'ed': 263,
#  b' b': 264,
#  b' to': 265,
#  b' and': 266,
#  b' h': 267,
#  b' f': 268,
#  b'in': 269,
#  b' T': 270,
#  b' wa': 271,
#  b're': 272,
#  b'it': 273,
#  b'ou': 274,
#  b' l': 275,
#  b' d': 276,
#  b' c': 277,
#  b' p': 278,
#  b'ay': 279,
#  b' m': 280,
#  b'er': 281,
#  b' was': 282,
#  b'om': 283,
#  b' The': 284,
#  b' he': 285,
#  b'is': 286,
#  b'ar': 287,
#  b' n': 288,
#  b'im': 289,
#  b'on': 290,
#  b' sa': 291,
#  b'id': 292,
#  b'll': 293,
#  b' ha': 294,
#  b' g': 295,
#  b'at': 296,
#  b' S': 297,
#  b'ing': 298,
#  b'ot': 299,
#  b'en': 300,
#  b'an': 301,
#  b'le': 302,
#  b'or': 303,
#  b'ir': 304,
#  b'am': 305,
#  b'et': 306,
#  b' H': 307,
#  b' it': 308,
#  b' th': 309,
#  b'ig': 310,
#  b' They': 311,
#  b' in': 312,
#  b'il': 313,
#  b' pl': 314,
#  b' He': 315,
#  b' "': 316,
#  b'ow': 317,
#  b'ver': 318,
#  b'ri': 319,
#  b'ut': 320,
#  b' be': 321,
#  b' u': 322,
#  b' said': 323,
#  b' play': 324,
#  b'ith': 325,
#  b' day': 326,
#  b' with': 327,
#  b'pp': 328,
#  b'On': 329,
#  b' o': 330,
#  b' y': 331,
#  b'oo': 332,
#  b'ked': 333,
#  b' r': 334,
#  b' her': 335,
#  b'ce': 336,
#  b' I': 337,
#  b' She': 338,
#  b'ld': 339,
#  b' Tim': 340,
#  b' his': 341,
#  b' st': 342,
#  b'ke': 343,
#  b' e': 344,
#  b' big': 345,
#  b'nt': 346,
#  b'ck': 347,
#  b' you': 348,
#  b'very': 349,
#  b'st': 350,
#  b've': 351,
#  b'end': 352,
#  b' on': 353,
#  b'un': 354,
#  b' happ': 355,
#  b'riend': 356,
#  b' friend': 357,
#  b'all': 358,
#  b'ily': 359,
#  b' L': 360,
#  b' they': 361,
#  b' we': 362,
#  b' had': 363,
#  b' not': 364,
#  b' li': 365,
#  b' up': 366,
#  b'her': 367,
#  b' want': 368,
#  b' of': 369,
#  b'ad': 370,
#  b'itt': 371,
#  b'se': 372,
#  b' B': 373,
#  b' do': 374,
#  b' happy': 375,
#  b'ent': 376,
#  b' very': 377,
#  b' M': 378,
#  b'es': 379,
#  b' that': 380,
#  b' saw': 381,
#  b'One': 382,
#  b"'s": 383,
#  b'ould': 384,
#  b' mom': 385,
#  b' for': 386,
#  b' sh': 387,
#  b'ittle': 388,
#  b' little': 389,
#  b' so': 390,
#  b' she': 391,
#  b'ch': 392,
#  b'ime': 393,
#  b' ne': 394,
#  b' nam': 395,
#  b'."': 396,
#  b' time': 397,
#  b' k': 398,
#  b'ound': 399,
#  b' there': 400,
#  b' named': 401,
#  b' sm': 402,
#  b' bo': 403,
#  b' were': 404,
#  b' Lily': 405,
#  b' wanted': 406,
#  b' but': 407,
#  b'out': 408,
#  b'The': 409,
#  b' friends': 410,
#  b'ved': 411,
#  b'!"': 412,
#  b'ht': 413,
#  b' Tom': 414,
#  b'ird': 415,
#  b'el': 416,
#  b' bird': 417,
#  b'al': 418,
#  b' an': 419,
#  b'ake': 420,
#  b' too': 421,
#  b'ome': 422,
#  b' It': 423,
#  b'ug': 424,
#  b'ide': 425,
#  b' went': 426,
#  b' wh': 427,
#  b' hel': 428,
#  b'Once': 429,
#  b' is': 430,
#  b' all': 431,
#  b' help': 432,
#  b'ue': 433,
#  b' loo': 434,
#  b' lo': 435,
#  b'ter': 436,
#  b' A': 437,
#  b' upon': 438,
#  b'ry': 439,
#  b'ore': 440,
#  b'ind': 441,
#  b' fun': 442,
#  b'get': 443,
#  b' toy': 444,
#  b'ill': 445,
#  b'ame': 446,
#  b' as': 447,
#  b' at': 448,
#  b'ra': 449,
#  b' j': 450,
#  b' did': 451,
#  b'gether': 452,
#  b' re': 453,
#  b'ur': 454,
#  b' se': 455,
#  b' together': 456,
#  b'ack': 457,
#  b' cat': 458,
#  b'ly': 459,
#  b' tre': 460,
#  b'ood': 461,
#  b'ic': 462,
#  b'ted': 463,
#  b' dog': 464,
#  b' could': 465,
#  b' can': 466,
#  b' their': 467,
#  b'ard': 468,
#  b'ec': 469,
#  b'ark': 470,
#  b' gir': 471,
#  b' played': 472,
#  b' him': 473,
#  b' ball': 474,
#  b'?"': 475,
#  b' girl': 476,
#  b'way': 477,
#  b' ro': 478,
#  b' go': 479,
#  b'hed': 480,
#  b'my': 481,
#  b' are': 482,
#  b' out': 483,
#  b' le': 484,
#  b' fr': 485,
#  b'ain': 486,
#  b' kn': 487,
#  b'hen': 488,
#  b' them': 489,
#  b'um': 490,
#  b"'t": 491,
#  b'ax': 492,
#  b' sad': 493,
#  b'ul': 494,
#  b' boy': 495,
#  b' tree': 496,
#  b'other': 497,
#  b' have': 498,
#  b' man': 499,
#  b' cl': 500,
#  b' loved': 501,
#  b' looked': 502,
#  b'oug': 503,
#  b' found': 504,
#  b' sp': 505,
#  b' star': 506,
#  b' Sue': 507,
#  b'one': 508,
#  b'hing': 509,
#  b' sc': 510,
#  b' back': 511,
#  b'own': 512,
#  b' Max': 513,
#  b'are': 514,
#  b' like': 515,
#  b'ful': 516,
#  b'side': 517,
#  b' me': 518,
#  b' bec': 519,
#  b' park': 520,
#  b'ight': 521,
#  b'ong': 522,
#  b' car': 523,
#  b'op': 524,
#  b'elt': 525,
#  b' One': 526,
#  b' liked': 527,
#  b' would': 528,
#  b' make': 529,
#  b'round': 530,
#  b' la': 531,
#  b' fa': 532,
#  b' felt': 533,
#  b'You': 534,
#  b' W': 535,
#  b'ell': 536,
#  b' see': 537,
#  b' But': 538,
#  b'omet': 539,
#  b' asked': 540,
#  b'ag': 541,
#  b' new': 542,
#  b' no': 543,
#  b'ice': 544,
#  b' Sam': 545,
#  b'ouse': 546,
#  b' started': 547,
#  b'ared': 548,
#  b' came': 549,
#  b' Ben': 550,
#  b' al': 551,
#  b' other': 552,
#  b'ought': 553,
#  b'iled': 554,
#  b' somet': 555,
#  b' ag': 556,
#  b' good': 557,
#  b' small': 558,
#  b'ss': 559,
#  b' br': 560,
#  b' smiled': 561,
#  b' say': 562,
#  b'ried': 563,
#  b'ade': 564,
#  b'ings': 565,
#  b'ob': 566,
#  b'pot': 567,
#  b' wor': 568,
#  b' find': 569,
#  b' ex': 570,
#  b'ia': 571,
#  b' away': 572,
#  b'ty': 573,
#  b' put': 574,
#  b' what': 575,
#  b' something': 576,
#  b' co': 577,
#  b' from': 578,
#  b' made': 579,
#  b' thought': 580,
#  b'ened': 581,
#  b' home': 582,
#  b' playing': 583,
#  b'ook': 584,
#  b' every': 585,
#  b' wal': 586,
#  b' mu': 587,
#  b'uc': 588,
#  b'ach': 589,
#  b'arn': 590,
#  b' Spot': 591,
#  b' ran': 592,
#  b'ile': 593,
#  b' F': 594,
#  b'ie': 595,
#  b' J': 596,
#  b'ave': 597,
#  b' again': 598,
#  b' some': 599,
#  b' laug': 600,
#  b'dd': 601,
#  b' house': 602,
#  b' down': 603,
#  b' fl': 604,
#  b'king': 605,
#  b' took': 606,
#  b' scared': 607,
#  b' pr': 608,
#  b'ny': 609,
#  b'ure': 610,
#  b' toys': 611,
#  b' learn': 612,
#  b' You': 613,
#  b'if': 614,
#  b' will': 615,
#  b' box': 616,
#  b'ick': 617,
#  b'ret': 618,
#  b'ab': 619,
#  b'ep': 620,
#  b' my': 621,
#  b' around': 622,
#  b' things': 623,
#  b' your': 624,
#  b'oud': 625,
#  b' bl': 626,
#  b'uck': 627,
#  b' when': 628,
#  b'ish': 629,
#  b' lived': 630,
#  b' fe': 631,
#  b' then': 632,
#  b' sun': 633,
#  b'as': 634,
#  b' sw': 635,
#  b',"': 636,
#  b' ch': 637,
#  b'us': 638,
#  b'pped': 639,
#  b' ab': 640,
#  b' Mia': 641,
#  b'ank': 642,
#  b' get': 643,
#  b'ucy': 644,
#  b'Tim': 645,
#  b'ump': 646,
#  b'Th': 647,
#  b' lot': 648,
#  b'ist': 649,
#  b'oth': 650,
#  b' tried': 651,
#  b'ap': 652,
#  b' know': 653,
#  b' says': 654,
#  b' got': 655,
#  b'ited': 656,
#  b' who': 657,
#  b' kne': 658,
#  b'ust': 659,
#  b' many': 660,
#  b'nder': 661,
#  b' int': 662,
#  b' about': 663,
#  b'Lily': 664,
#  b' pret': 665,
#  b' dec': 666,
#  b' any': 667,
#  b' red': 668,
#  b' D': 669,
#  b'ive': 670,
#  b' knew': 671,
#  b'ace': 672,
#  b'ous': 673,
#  b' more': 674,
#  b'ise': 675,
#  b' care': 676,
#  b'ally': 677,
#  b' pic': 678,
#  b'au': 679,
#  b'qu': 680,
#  b' hug': 681,
#  b' Lucy': 682,
#  b' learned': 683,
#  b' po': 684,
#  b' water': 685,
#  b'fter': 686,
#  b' v': 687,
#  b' became': 688,
#  b' best': 689,
#  b'ause': 690,
#  b' op': 691,
#  b' gre': 692,
#  b' exc': 693,
#  b'urp': 694,
#  b'ways': 695,
#  b'\xe2\x80': 696,
#  b' outside': 697,
#  b' laughed': 698,
#  b' look': 699,
#  b' always': 700,
#  b' decid': 701,
#  b' show': 702,
#  b' un': 703,
#  b'ant': 704,
#  b' Bob': 705,
#  b' room': 706,
#  b'fe': 707,
#  b' decided': 708,
#  b' ho': 709,
#  b' because': 710,
#  b' So': 711,
#  b' into': 712,
#  b' eat': 713,
#  b'ite': 714,
#  b' jump': 715,
#  b' And': 716,
#  b' pe': 717,
#  b' both': 718,
#  b'ers': 719,
#  b' Mom': 720,
#  b' dad': 721,
#  b'They': 722,
#  b'udd': 723,
#  b' ke': 724,
#  b' one': 725,
#  b'nn': 726,
#  b' this': 727,
#  b' excited': 728,
#  b' fast': 729,
#  b' nice': 730,
#  b' E': 731,
#  b' feel': 732,
#  b'Tom': 733,
#  b'Yes': 734,
#  b' run': 735,
#  b' long': 736,
#  b' told': 737,
#  b' sk': 738,
#  b' am': 739,
#  b'urpr': 740,
#  b'our': 741,
#  b' inside': 742,
#  b'ull': 743,
#  b' tr': 744,
#  b' surpr': 745,
#  b' mo': 746,
#  b'ink': 747,
#  b' pretty': 748,
#  b'iny': 749,
#  b' sor': 750,
#  b'Wh': 751,
#  b' take': 752,
#  b'og': 753,
#  b' sl': 754,
#  b' each': 755,
#  b' gave': 756,
#  b' much': 757,
#  b' gra': 758,
#  b'lew': 759,
#  b'nna': 760,
#  b' rock': 761,
#  b' how': 762,
#  b' str': 763,
#  b'ara': 764,
#  b'imal': 765,
#  b' animal': 766,
#  b'ged': 767,
#  b' need': 768,
#  b' than': 769,
#  b'But': 770,
#  b'ven': 771,
#  b'etter': 772,
#  b' tow': 773,
#  b' or': 774,
#  b' C': 775,
#  b' under': 776,
#  b'ess': 777,
#  b' old': 778,
#  b' sorry': 779,
#  b'ge': 780,
#  b'ised': 781,
#  b'ro': 782,
#  b'urt': 783,
#  b' cle': 784,
#  b' fish': 785,
#  b' walked': 786,
#  b' clo': 787,
#  b'and': 788,
#  b' bear': 789,
#  b'ft': 790,
#  b'ase': 791,
#  b'ast': 792,
#  b' hand': 793,
#  b'urn': 794,
#  b' We': 795,
#  b' kind': 796,
#  b' His': 797,
#  b' te': 798,
#  b'here': 799,
#  b' happened': 800,
#  b' just': 801,
#  b' flow': 802,
#  b' food': 803,
#  b' list': 804,
#  b' didn': 805,
#  b' animals': 806,
#  b' hig': 807,
#  b'pl': 808,
#  b' near': 809,
#  b' wat': 810,
#  b' ide': 811,
#  b' try': 812,
#  b'ched': 813,
#  b' sky': 814,
#  b'ine': 815,
#  b' sn': 816,
#  b'ving': 817,
#  b' fi': 818,
#  b'rom': 819,
#  b' us': 820,
#  b' idea': 821,
#  b' better': 822,
#  b' Amy': 823,
#  b' bug': 824,
#  b' heard': 825,
#  b'gry': 826,
#  b' its': 827,
#  b' tw': 828,
#  b' let': 829,
#  b'pec': 830,
#  b'ate': 831,
#  b'able': 832,
#  b'ff': 833,
#  b' en': 834,
#  b' careful': 835,
#  b' share': 836,
#  b'ex': 837,
#  b' if': 838,
#  b'Thank': 839,
#  b'Mom': 840,
#  b' fly': 841,
#  b' stor': 842,
#  b'ial': 843,
#  b' flew': 844,
#  b'more': 845,
#  b' anymore': 846,
#  b' Th': 847,
#  b' spec': 848,
#  b' special': 849,
#  b'ion': 850,
#  b' com': 851,
#  b' lots': 852,
#  b' never': 853,
#  b' by': 854,
#  b'lf': 855,
#  b'ream': 856,
#  b' dan': 857,
#  b' bu': 858,
#  b' fo': 859,
#  b' wind': 860,
#  b' don': 861,
#  b' tal': 862,
#  b' clean': 863,
#  b'ort': 864,
#  b' gr': 865,
#  b' love': 866,
#  b'rm': 867,
#  b'ber': 868,
#  b' end': 869,
#  b'\n\n': 870,
#  b' Then': 871,
#  b'ople': 872,
#  b' even': 873,
#  b' mag': 874,
#  b' hard': 875,
#  b' shiny': 876,
#  b'udden': 877,
#  b' fore': 878,
#  b' over': 879,
#  b' cake': 880,
#  b'ak': 881,
#  b' book': 882,
#  b' col': 883,
#  b' turn': 884,
#  b' fam': 885,
#  b' bad': 886,
#  b' safe': 887,
#  b' after': 888,
#  b'ady': 889,
#  b' Anna': 890,
#  b'uddenly': 891,
#  b' people': 892,
#  b' proud': 893,
#  b' Every': 894,
#  b' surprised': 895,
#  b'pected': 896,
#  b'Let': 897,
#  b' high': 898,
#  b' cu': 899,
#  b' hurt': 900,
#  b' come': 901,
#  b'imb': 902,
#  b'arden': 903,
#  b' door': 904,
#  b' garden': 905,
#  b'bb': 906,
#  b' ground': 907,
#  b' opened': 908,
#  b' picked': 909,
#  b' loud': 910,
#  b' climb': 911,
#  b'expected': 912,
#  b' unexpected': 913,
#  b' gl': 914,
#  b' che': 915,
#  b'ild': 916,
#  b' im': 917,
#  b'As': 918,
#  b' give': 919,
#  b' way': 920,
#  b'ail': 921,
#  b"'m": 922,
#  b' thanked': 923,
#  b' color': 924,
#  b' blue': 925,
#  b' still': 926,
#  b' ever': 927,
#  b' hugged': 928,
#  b' From': 929,
#  b' call': 930,
#  b' far': 931,
#  b'ip': 932,
#  b' Her': 933,
#  b' Sara': 934,
#  b' When': 935,
#  b'No': 936,
#  b' off': 937,
#  b' magic': 938,
#  b'iz': 939,
#  b'ough': 940,
#  b'age': 941,
#  b'ummy': 942,
#  b' K': 943,
#  b' jumped': 944,
#  b' should': 945,
#  b' family': 946,
#  b' par': 947,
#  b'ool': 948,
#  b' kid': 949,
#  b' smile': 950,
#  b'hes': 951,
#  b'uff': 952,
#  b' place': 953,
#  b'kay': 954,
#  b' walk': 955,
#  b' now': 956,
#  b'ct': 957,
#  b' In': 958,
#  b' great': 959,
#  b'em': 960,
#  b'ture': 961,
#  b' qu': 962,
#  b'les': 963,
#  b' strong': 964,
#  b' stay': 965,
#  b' unt': 966,
#  b' sto': 967,
#  b'aut': 968,
#  b' forest': 969,
#  b'ane': 970,
#  b' bra': 971,
#  b'itty': 972,
#  b' P': 973,
#  b' frog': 974,
#  b' bro': 975,
#  b' until': 976,
#  b'oon': 977,
#  b' beaut': 978,
#  b'dy': 979,
#  b' squ': 980,
#  b' stick': 981,
#  b'xt': 982,
#  b' next': 983,
#  b' boat': 984,
#  b'lease': 985,
#  b'ning': 986,
#  b' happily': 987,
#  b' listen': 988,
#  b'aking': 989,
#  b' kids': 990,
#  b' tra': 991,
#  b'ies': 992,
#  b'iful': 993,
#  b' beautiful': 994,
#  b' app': 995,
#  b'th': 996,
#  b' helped': 997,
#  b' dra': 998,
#  b' showed': 999,
#  ...}

# %%
def encode(text):
   PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
   import regex as re
   
   text_merged_encoded = list()
   for match in re.finditer(PAT, text): # Process every pre-token finded by the regex
      match_encoded = match.group(0).encode("utf-8")
      tuple_of_bytes = tuple([match_encoded[i:i+1] for i in range(len(match_encoded)) ])
      #Now given the tuple of bytes I have to apply the merges in order or appearance
      i = 0
      while i < len(merges) and len(tuple_of_bytes)>1:
         pair_to_find = merges[i]
         j = 0
         merged_pre_token = list()
         # print(tuple_of_bytes)
         while j < len(tuple_of_bytes):
            if j < len(tuple_of_bytes) - 1 and pair_to_find[0] == tuple_of_bytes[j] and pair_to_find[1] == tuple_of_bytes[j + 1]:
               merged_pre_token.append(pair_to_find[0] + pair_to_find[1])
               j+=2
            else:
               merged_pre_token.append(tuple_of_bytes[j])
               j+=1
         tuple_of_bytes =tuple( merged_pre_token)
         # print(tuple_of_bytes)
         i+= 1
      # break
      
      pre_token_integer = list()
      for byte in tuple_of_bytes:
         text_merged_encoded.append(reversed_vocab[byte])
      
   return text_merged_encoded

# %%
tuple_of_bytes = (b't',b'kl')

# %%
len(tuple_of_bytes)
# Out:
# 2

# %%
encode(text = " tom hello tttt t")
# Out:
# [1885, 2560, 256, 3288, 116, 256]

# %%
vocab[1885], vocab[2560], vocab[256] + vocab [3288] + vocab[116], vocab[256] #It works yay!!!
# Out:
# (b' tom', b' hello', b' tttt', b' t')

# %%
def decode(ids):
   result = b"".join(vocab[id] for id in ids)
   return result.decode("utf-8", errors="replace")

# %%
decode(encode(text))
# Out:
# ' tom hello tttt t'

# %%
from pathlib import Path

print(Path.cwd())

for path in Path("..").rglob("*.py"):
   if "token" in path.name.lower() or "bpe" in path.name.lower():
      print(path)
# Out:
# /home/tom/machine-learning/assignment1-basics/cs336_basics
# ../tests/test_tokenizer.py
# ../tests/test_train_bpe.py
# ../.venv/lib/python3.13/site-packages/pygments/token.py
# ../.venv/lib/python3.13/site-packages/asttokens/mark_tokens.py
# ../.venv/lib/python3.13/site-packages/asttokens/asttokens.py
# ../.venv/lib/python3.13/site-packages/packaging/_tokenizer.py
# ../.venv/lib/python3.13/site-packages/prompt_toolkit/token.py
# ../.venv/lib/python3.13/site-packages/yaml/tokens.py
# ../.venv/lib/python3.13/site-packages/setuptools/_vendor/packaging/_tokenizer.py
# ../.venv/lib/python3.13/site-packages/torch/export/_remove_effect_tokens_pass.py
# ../.venv/lib/python3.13/site-packages/wandb/sdk/lib/service/service_token.py
# ../.venv/lib/python3.13/site-packages/wandb/vendor/pygments/token.py
# ../.venv/lib/python3.13/site-packages/parso/python/token.py
# ../.venv/lib/python3.13/site-packages/parso/python/tokenize.py
# ../.venv/lib/python3.13/site-packages/IPython/utils/tokenutil.py
# ../cs336_basics/bpe/bpe_training.py
# ../cs336_basics/bpe/pretokenization_example.py
# ../cs336_basics/bpe/tokenizer.py
# ../cs336_basics/scripts/profile_bpe.py
# ../cs336_basics/scripts/train_bpe_tinystories.py
# ../cs336_basics/scripts/train_bpe_owt.py

# %%
from cs336_basics.bpe.tokenizer import Tokenizer
with open("../data/tinystories_vocab.pkl", "rb") as f:
   vocab = pickle.load(f)

with open("../data/tinystories_merges.pkl", "rb") as f:
   merges = pickle.load(f)

tokenizer = Tokenizer(
   vocab=vocab,
   merges=merges,
   special_tokens=["<|endoftext|>"],
)

# %%
with open("../data/TinyStoriesV2-GPT4-valid.txt", "r", encoding="utf-8") as f:
   text = f.read()

documents = text.split("<|endoftext|>")

documents = [
   document
   for document in documents
   if document.strip()
]

print("Documents:", len(documents))
# Out:
# Documents: 27630

# %%
random.seed(42)

sampled_documents = random.sample(documents, 10)

# %%
for i, document in enumerate(sampled_documents):
   print(f"Document {i}")
   print(document[:200])
   print()
# Out:
# Document 0
#
# Once upon a time, in a little town, there was a man with a big mustache. He was very bossy. Every day, he told the people what to do. The people did not like him, but they did what he said.
# One day,
#
# Document 1
#
#
#
# Ben and Mia were playing on the beach with their sand toys. They made a big castle with towers and walls and a moat. They were having fun, but they were also very tired from the sun and the waves.
#
#
# Document 2
#
# Once upon a time, there was a big play. Many kids came to watch. One kid named Tom had to act in the play. He had to act like a hero who saves the day. Tom was very excited.
# In the play, there was a
#
# Document 3
#
#
# Mother woke up alert. She put on her coat and shoes. She wanted to go outside to the park. Mother put on her hat and went outside. At the park she saw birds and squirrels. Mother was alert and looke
#
# Document 4
#
#
#
# Tim and Sam like to watch team games on TV. They cheer for their favorite team, the red team. They wear red shirts and hats to show their love.
# One day, they watch a game with their dad. The red te
#
# Document 5
#
# Once upon a time, there was a big, warm sun. It was so wide and bright that it made everyone happy. The sun loved to celebrate with all the animals and people on Earth.
# One day, the sun decided to ha
#
# Document 6
#
# Once upon a time, there was a wild robot named Rob. Rob liked to play with his best friend, a little boy named Tim. They played in the park every day.
# One day, while they were playing, Rob said, "Tim
#
# Document 7
#
# One day, a little boy named Tim saw a pie on the table. He wanted to eat it, but it was too high for him to reach. He tried to stand on his toes, but he still could not get it. Tim started to struggl
#
# Document 8
#
# One day, a big sun named Sunny was very popular. All the kids loved to play when Sunny was out. Every day, Sunny would rise in the morning and go to sleep at night. At noon, Sunny was the highest in
#
# Document 9
#
# Once upon a time, in a small town, there was a big spring. The spring had a lot of water. The water was sour, but the people in the town still liked it.
# One day, a girl named Lily went to the spring

# %%
total_bytes = 0
total_tokens = 0

for document in sampled_documents:
   document_bytes = len(document.encode("utf-8"))
   token_ids = tokenizer.encode(document)

   total_bytes+= document_bytes
   total_tokens += len(token_ids)

ratio = total_bytes/total_tokens
ratio
# Out:
# 4.025628856193641

# %% [markdown]
# On 10 sampled TinyStories documents, the 10K-vocabulary tokenizer achieved a compression ratio of approximately 4 bytes/token, meaning that each token represents about 4 bytes of UTF-8 text on average.

# %%
#Using the tokenizer of tinystories on open web text to see the ratio
owt_path = "../data/owt_valid.txt"
separator = "<|endoftext|>"

sampled_owt_documents = []

buffer = ""

with open(owt_path, "r", encoding="utf-8") as f:
   for line in f:
      buffer += line

      while separator in buffer:
         document, buffer = buffer.split(separator, 1)

         if document.strip():
            sampled_owt_documents.append(document)

         if len(sampled_owt_documents) == 10:
            break

      if len(sampled_owt_documents) == 10:
         break

print("Documents:", len(sampled_owt_documents))
# Out:
# Documents: 10

# %%
for i, document in enumerate(sampled_owt_documents):
   print(f"Document {i}")
   print(document[:200])
   print()
# Out:
# Document 0
# LOUISVILLE, Ky. — A few unflattering reviews are to be expected with any hotel, particularly one whose rates start at $49 per night. But while complaints about shabby rooms and thin towels are common
#
# Document 1
# Years had led up to this. Countless hours of training with her team, private sparring with Blake, all those boring classes, everything. Roman Torchwick was going down, tonight. Yang was running throug
#
# Document 2
# Ethan Dean is on the verge of financial ruin because the city of Winona won't let him do what countless property owners have done for centuries: rent out his home.
#
# Dean serves as an advisor in Iraq a
#
# Document 3
# Kanger SUBVOD Full Sub Ohm Kit
#
# Made with, the Kanger SUBVOD is. Not only is it, the Kanger SUBVOD kitneeded for- not to mention it's a really good looking ecig,• 1300mAh integrated battery cell• 18mm
#
# Document 4
# Hundreds of supporters of deposed Egyptian President Mohamed Morsi remain trapped in a mosque near Cairo's Ramses Square after security forces escorted several of them out.
#
# The standoff at the Egypti
#
# Document 5
# – When Cara Jones let her black-and-white pit bull, “Creature,” out Thursday night to relieve herself at the end of William Street, she heard something unusual coming from the woods. “I kept hearing s
#
# Document 6
# The first time I heard of this still-without-US-distribution German sci-fi indie was casually browsing through Facebook and the image of a scantily clad teenage girl protectively clutching to a little
#
# Document 7
# newsheadlines ROYAL BLOOD SPORTS
#
# A few months before the Queen's German husband, Prince Philip, launched the World Wildlife Fund in 1961, he went on a tiger hunt with the Queen. A tiger was lured int
#
# Document 8
# The Daily Stormer website, which promotes neo-Nazi material, was dropped by the GoDaddy and Google servers. (Photo11: Daily Stormer screenshot)
#
# Electronic Frontier Foundation, a digital rights group,
#
# Document 9
# Two separate teams of researchers have found evidence for a theorized type of massless particle known as a “Weyl fermion.” The discovery was made by scientists at Princeton University in New Jersey an

# %%
total_bytes = 0
total_tokens = 0

for document in sampled_owt_documents:
   document_bytes = len(document.encode("utf-8"))
   token_ids = tokenizer.encode(document)

   total_bytes += document_bytes
   total_tokens += len(token_ids)

owt_ratio_with_tinystories_tokenizer = total_bytes / total_tokens

print("OWT with TinyStories tokenizer:")
print(owt_ratio_with_tinystories_tokenizer, "bytes/token")
# Out:
# OWT with TinyStories tokenizer:
# 3.404628567573038 bytes/token

# %%
tinystories_ratio = ratio

print("TinyStories:", tinystories_ratio, "bytes/token")
print("OWT:", owt_ratio_with_tinystories_tokenizer, "bytes/token")
# Out:
# TinyStories: 4.025628856193641 bytes/token
# OWT: 3.404628567573038 bytes/token

# %%
import time
with open("../data/TinyStoriesV2-GPT4-valid.txt", "r", encoding="utf-8") as f:
   benchmark_text = f.read()

benchmark_bytes = len(benchmark_text.encode("utf-8"))

print("Benchmark size:", benchmark_bytes, "bytes")
# Out:
# Benchmark size: 22502601 bytes

# %%
start = time.perf_counter()

token_ids = tokenizer.encode(benchmark_text)

end = time.perf_counter()

elapsed = end - start

print("Elapsed:", elapsed, "seconds")
# Out:
# Elapsed: 35.270713475001685 seconds

# %%
throughput = benchmark_bytes / elapsed

print("Throughput:", throughput, "bytes/second")
print("Throughput:", throughput / 1e6, "MB/s")
# Out:
# Throughput: 637996.7622698884 bytes/second
# Throughput: 0.6379967622698884 MB/s

# %%
pile_bytes = 825 * 1e9

estimated_seconds = pile_bytes / throughput
estimated_hours = estimated_seconds / 3600
estimated_days = estimated_hours / 24

print("Estimated seconds:", estimated_seconds)
print("Estimated hours:", estimated_hours)
print("Estimated days:", estimated_days)
# Out:
# Estimated seconds: 1293110.0105661736
# Estimated hours: 359.19722515727045
# Estimated days: 14.966551048219602
